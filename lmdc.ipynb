# %%
# Check GPU type
# !nvidia-smi
# Out:
# Tue Oct 22 22:06:27 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 561.09                 Driver Version: 561.09         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1050 Ti   WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   55C    P8             N/A / ERR!  |       0MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A     11876    C+G   ...inaries\Win64\EpicGamesLauncher.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# Install ultralytics
# !pip -q install  ultralytics

# %%
# Import libraries
import pandas as pd
import os
from pathlib import Path
import shutil
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
import cv2
import yaml
import matplotlib.pyplot as plt
from ultralytics import YOLO
import multiprocessing

# %%
# check the current working directory
# os.chdir('C:/Users/lamem/OneDrive/Documents/GHD/Microsoft-Learn-Location-Mention-Recognition-Challenge')
os.chdir('C:/Users/abelm/repos/Lacuna-Malaria-Detection-Challenge')
print(os.getcwd())
# Out:
# C:\Users\abelm\repos\Lacuna-Malaria-Detection-Challenge

# %%
# Path to where your data is stored
DATA_DIR = Path('./data')

# Preview data files available
os.listdir(DATA_DIR)
# Out:
# ['images', 'SampleSubmission.csv', 'Test.csv', 'Train.csv']

# %%
# Set up directoris for training a yolo model

# Images directories
DATASET_DIR = Path('datasets/dataset')
IMAGES_DIR = DATASET_DIR / 'images'
TRAIN_IMAGES_DIR = IMAGES_DIR / 'train'
VAL_IMAGES_DIR = IMAGES_DIR / 'val'
TEST_IMAGES_DIR = IMAGES_DIR / 'test'

# Labels directories
LABELS_DIR = DATASET_DIR / 'labels'
TRAIN_LABELS_DIR = LABELS_DIR / 'train'
VAL_LABELS_DIR = LABELS_DIR / 'val'
TEST_LABELS_DIR = LABELS_DIR / 'test'

# %%
# Unzip images to 'images' dir
# shutil.unpack_archive(DATA_DIR / 'images.zip', 'images')

# %%
# Load train and test files
train = pd.read_csv(DATA_DIR / 'Train.csv')
test = pd.read_csv(DATA_DIR / 'Test.csv')
ss = pd.read_csv(DATA_DIR / 'SampleSubmission.csv')

# Add an image_path column
train['image_path'] = [Path('data/images/' + x) for x in train.Image_ID]
test['image_path'] = [Path('data/images/' + x) for x in test.Image_ID]

# Map str classes to ints (label encoding targets)
train['class_id'] = train['class'].map({'Trophozoite': 0, 'WBC': 1, 'NEG': 2})

# Preview the head of the train set
train.head()
# Out:
#             Image_ID        class  confidence  ymin  xmin  ymax  xmax  \
# 0  id_u3q6jdck4j.jpg  Trophozoite         1.0   712  1241   737  1270
# 1  id_a6cl90trri.jpg  Trophozoite         1.0   558  1566   600  1604
# 2  id_qvc2le9sm8.jpg  Trophozoite         1.0  1317  2788  1448  2914
# 3  id_w8xnbd5rvm.jpg  Trophozoite         1.0   925  1744  1041  1823
# 4  id_6dop09rk02.jpg          NEG         1.0     0     0     0     0
#
#                       image_path  class_id
# 0  data\images\id_u3q6jdck4j.jpg         0
# 1  data\images\id_a6cl90trri.jpg         0
# 2  data\images\id_qvc2le9sm8.jpg         0
# 3  data\images\id_w8xnbd5rvm.jpg         0
# 4  data\images\id_6dop09rk02.jpg         2

# %%
# Filter out NEG class (Negative images - this images have no Trophozoite nor WBC in them)
# Yolo reccomends that when creating labels for negative images, you leave them empty
# https://github.com/ultralytics/yolov5/issues/3218
# As this is a starter nb, we will ignore the negative images
train = train[~(train['class'] == 'NEG')].reset_index(drop = True)

# %%
# Split data into training and validation
train_unique_imgs_df = train.drop_duplicates(subset = ['Image_ID'], ignore_index = True)
X_train, X_val = train_test_split(train_unique_imgs_df, test_size = 0.25, stratify=train_unique_imgs_df['class'], random_state=42)

X_train = train[train.Image_ID.isin(X_train.Image_ID)]
X_val = train[train.Image_ID.isin(X_val.Image_ID)]

# Check shapes of training and validation data
X_train.shape, X_val.shape
# Out:
# ((17354, 9), (5488, 9))

# %%
# Preview target distribution, seems there a class imbalance that needs to be handled
X_train['class'].value_counts(normalize = True), X_val['class'].value_counts(normalize = True)
# Out:
# (class
#  Trophozoite    0.688141
#  WBC            0.311859
#  Name: proportion, dtype: float64,
#  class
#  Trophozoite    0.709913
#  WBC            0.290087
#  Name: proportion, dtype: float64)

# %%
# Check if dirs exist, if they do, remove them, otherwise create them.
# This only needs to run once
for DIR in [TRAIN_IMAGES_DIR,VAL_IMAGES_DIR, TEST_IMAGES_DIR, TRAIN_LABELS_DIR,VAL_LABELS_DIR,TEST_LABELS_DIR]:
  if DIR.exists():
    shutil.rmtree(DIR)
  DIR.mkdir(parents=True, exist_ok = True)

# %%
# Copy train, val and test images to their respective dirs
for img in tqdm(X_train.image_path.unique()):
  shutil.copy(img, TRAIN_IMAGES_DIR / img.parts[-1])

for img in tqdm(X_val.image_path.unique()):
  shutil.copy(img, VAL_IMAGES_DIR / img.parts[-1])

for img in tqdm(test.image_path.unique()):
  shutil.copy(img, TEST_IMAGES_DIR / img.parts[-1])
# Out:
#   0%|          | 0/1544 [00:00<?, ?it/s]
#   0%|          | 0/515 [00:00<?, ?it/s]
#   0%|          | 0/1178 [00:00<?, ?it/s]

# %%
# Function to convert the bboxes to yolo format and save them
def save_yolo_annotation(row):
    image_path, class_id, output_dir = row['image_path'], row['class_id'], row['output_dir']

    img = cv2.imread(image_path)
    # print image path
    print(image_path)
    if img is None:
        raise ValueError(f"Could not read image from path: {image_path}")

    height, width, _ = img.shape

    label_file = Path(output_dir) / f"{Path(image_path).stem}.txt"

    ymin, xmin, ymax, xmax = row['ymin'], row['xmin'], row['ymax'], row['xmax']

    # Normalize the coordinates
    x_center = (xmin + xmax) / 2 / width
    y_center = (ymin + ymax) / 2 / height
    bbox_width = (xmax - xmin) / width
    bbox_height = (ymax - ymin) / height

    with open(label_file, 'a') as f:
        f.write(f"{class_id} {x_center:.6f} {y_center:.6f} {bbox_width:.6f} {bbox_height:.6f}\n")

# %%
X_train.head()
# Out:
#             Image_ID        class  confidence  ymin  xmin  ymax  xmax  \
# 0  id_u3q6jdck4j.jpg  Trophozoite         1.0   712  1241   737  1270
# 2  id_qvc2le9sm8.jpg  Trophozoite         1.0  1317  2788  1448  2914
# 3  id_w8xnbd5rvm.jpg  Trophozoite         1.0   925  1744  1041  1823
# 4  id_i7r9hkhxvx.jpg          WBC         1.0   846   906   903   963
# 5  id_fzogq9kijh.jpg          WBC         1.0   641   280   711   373
#
#                       image_path  class_id
# 0  data\images\id_u3q6jdck4j.jpg         0
# 2  data\images\id_qvc2le9sm8.jpg         0
# 3  data\images\id_w8xnbd5rvm.jpg         0
# 4  data\images\id_i7r9hkhxvx.jpg         1
# 5  data\images\id_fzogq9kijh.jpg         1

# %%
# Save annotations without parallelization
def process_dataset(dataframe, output_dir):
    dataframe['output_dir'] = output_dir
    for _, row in tqdm(dataframe.iterrows(), total=len(dataframe)):
        save_yolo_annotation(row)

# %%
# Save train and validation labels to their respective dirs
process_dataset(X_train, TRAIN_LABELS_DIR)
process_dataset(X_val, VAL_LABELS_DIR)
# Out:
# C:\Users\abelm\AppData\Local\Temp\ipykernel_14640\3787764289.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['output_dir'] = output_dir
#   0%|          | 0/17354 [00:00<?, ?it/s]
# data\images\id_u3q6jdck4j.jpg
# data\images\id_qvc2le9sm8.jpg
# data\images\id_w8xnbd5rvm.jpg
# data\images\id_i7r9hkhxvx.jpg
# data\images\id_fzogq9kijh.jpg
# data\images\id_2phbgf1x5m.jpg
# data\images\id_8l8zssuabc.jpg
# data\images\id_pwiv4czvne.jpg
# data\images\id_ylrsd2a6k4.jpg
# data\images\id_n0dqkovtp3.jpg
# data\images\id_5bbz3srksa.jpg
# data\images\id_e3tep47339.jpg
# data\images\id_nzkpf8tr8o.jpg
# data\images\id_7chz2q4dsm.jpg
# data\images\id_9cikz22vmm.jpg
# data\images\id_331urb6uko.jpg
# data\images\id_vmj225uyxh.jpg
# data\images\id_lpc9b0h4yl.jpg
# data\images\id_5gudsszz0t.jpg
# data\images\id_tmtzoe9bns.jpg
# data\images\id_tgqn7f4tx0.jpg
# data\images\id_fa626uztwq.jpg
# data\images\id_pnave1opt9.jpg
# data\images\id_napzy4l85v.jpg
# data\images\id_0v91pruf44.jpg
# data\images\id_8ztw2t9cet.jpg
# data\images\id_r1h52tth8l.jpg
# data\images\id_xculy3gzpk.jpg
# data\images\id_z0i61ad0tq.jpg
# data\images\id_vvcixbrht6.jpg
# data\images\id_vtppfsimst.jpg
# data\images\id_j0s3jncce7.jpg
# data\images\id_xa4qfbdy8x.jpg
# data\images\id_8x0h7f3orn.jpg
# data\images\id_yfgqifa1av.jpg
# data\images\id_q4pmxshnf8.jpg
# data\images\id_4xe7v3uzb0.jpg
# data\images\id_az75itcgjz.jpg
# data\images\id_iwm2km59xp.jpg
# data\images\id_iidcwndfgq.jpg
# data\images\id_pwiv4czvne.jpg
# data\images\id_cv5yf1d2ap.jpg
# data\images\id_rqr7ifphi8.jpg
# data\images\id_b8vydytsyy.jpg
# data\images\id_io6mu601ef.jpg
# data\images\id_e4124p2abl.jpg
# data\images\id_2v40bfhybf.jpg
# data\images\id_xcv8hacv2o.jpg
# data\images\id_6t3jc3jcbq.jpg
# data\images\id_wr1bsozdoh.jpg
# data\images\id_zr4uyveglu.jpg
# data\images\id_rdy8ijad2a.jpg
# data\images\id_ixxqgodncy.jpg
# data\images\id_qcgac2hzwm.jpg
# data\images\id_6qr9x3f384.jpg
# data\images\id_wbxjec4uq4.jpg
# data\images\id_ulanlfsxbd.jpg
# data\images\id_a1jdwsbpyl.jpg
# data\images\id_dg0icorzno.jpg
# data\images\id_ffc6hl3147.jpg
# data\images\id_2gp13u7qvy.jpg
# data\images\id_re74wr6nyy.jpg
# data\images\id_ulanlfsxbd.jpg
# data\images\id_g9j9rxm05s.jpg
# data\images\id_19lavqwwve.jpg
# data\images\id_r90wmxlo7g.jpg
# data\images\id_k31xcsf57u.jpg
# data\images\id_3dvqhi5yc2.jpg
# data\images\id_4p97xqczln.jpg
# data\images\id_6r4u8vcjay.jpg
# data\images\id_zdg96srigj.jpg
# data\images\id_is6qvm3hoj.jpg
# data\images\id_ezd6x40fd0.jpg
# data\images\id_5vugns5i4r.jpg
# data\images\id_7v191des6a.jpg
# data\images\id_uin77hhkwi.jpg
# data\images\id_7l5fy1nin2.jpg
# data\images\id_kmh7ea7qta.jpg
# data\images\id_9ynomawl38.jpg
# data\images\id_138trbgjle.jpg
# data\images\id_cm79arin5l.jpg
# data\images\id_e5rea6wgy6.jpg
# data\images\id_vqxavxbgqv.jpg
# data\images\id_1kx1qtnqf6.jpg
# data\images\id_k061rd9uty.jpg
# data\images\id_tdb81ada4s.jpg
# data\images\id_fmofpxvw0i.jpg
# data\images\id_641yuyjn1f.jpg
# data\images\id_ns0ww9t3ju.jpg
# data\images\id_sv9q2kedlr.jpg
# data\images\id_fvt1r4srx5.jpg
# data\images\id_b9i2zz9yug.jpg
# data\images\id_wq2owxeg15.jpg
# data\images\id_mty3c1iqq1.jpg
# data\images\id_7zzh2ff8h1.jpg
# data\images\id_99dqny1a0l.jpg
# data\images\id_m52amtpkzq.jpg
# data\images\id_ch6r0g46fr.jpg
# data\images\id_warx3mh4mf.jpg
# data\images\id_f42a2gqph2.jpg
# data\images\id_wd51nh9072.jpg
# data\images\id_5bbz3srksa.jpg
# data\images\id_4cotsn0obm.jpg
# data\images\id_crenkaw87t.jpg
# data\images\id_nk6b8hdvu3.jpg
# data\images\id_8aq7cnhtl5.jpg
# data\images\id_tbe6fmgu8x.jpg
# data\images\id_6kxxaxsy7s.jpg
# data\images\id_v7a1nqldvn.jpg
# data\images\id_rjjkcsmkbh.jpg
# data\images\id_1b9vlj7csf.jpg
# data\images\id_f56uxwa2ey.jpg
# data\images\id_l0tm7il1xn.jpg
# data\images\id_6fbhkyv1rd.jpg
# data\images\id_ie9392cr9c.jpg
# data\images\id_p5cwsp3ed1.jpg
# data\images\id_geau0p533v.jpg
# data\images\id_nfscssxd2u.jpg
# data\images\id_wczc5k3dwj.jpg
# data\images\id_9ctex4nrc1.jpg
# data\images\id_ssc5cizh06.jpg
# data\images\id_r3qk3gs23y.jpg
# data\images\id_5bbz3srksa.jpg
# data\images\id_0fdars2kkw.jpg
# data\images\id_8og9rd87b0.jpg
# data\images\id_4wkzpeu6or.jpg
# data\images\id_48b1s36zmc.jpg
# data\images\id_5r1k5g43dg.jpg
# data\images\id_yd3tmwvvgu.jpg
# data\images\id_3rrbg84f29.jpg
# data\images\id_bt2zp2gbmn.jpg
# data\images\id_idjqlz4ppb.jpg
# data\images\id_2rtwh0u17x.jpg
# data\images\id_r90wmxlo7g.jpg
# data\images\id_ks4su5m3hj.jpg
# data\images\id_jjl4az6opt.jpg
# data\images\id_18zr61kc0a.jpg
# data\images\id_k061rd9uty.jpg
# data\images\id_cg82fmj278.jpg
# data\images\id_n9bbcos7p2.jpg
# data\images\id_2ngng2qenk.jpg
# data\images\id_4y1b6jhgue.jpg
# data\images\id_a2myf5oy8r.jpg
# data\images\id_by6e6shi2z.jpg
# data\images\id_unbxbat1t9.jpg
# data\images\id_sin11o52ho.jpg
# data\images\id_d7pd07ec8m.jpg
# data\images\id_4p9ymf6p3s.jpg
# data\images\id_ykdw2stt19.jpg
# data\images\id_e23dyybn4a.jpg
# data\images\id_9t9vkxsw2v.jpg
# data\images\id_nl3aeas2wu.jpg
# data\images\id_b1z4o0mupl.jpg
# data\images\id_i5tsin8ztt.jpg
# data\images\id_ki6qkk13sm.jpg
# data\images\id_9c48ivvo8u.jpg
# data\images\id_yd3tmwvvgu.jpg
# data\images\id_rdy8ijad2a.jpg
# data\images\id_wij48tbsif.jpg
# data\images\id_3l42ck1ho6.jpg
# data\images\id_i7nitsscaw.jpg
# data\images\id_os8jopl2gg.jpg
# data\images\id_1xpbtfb4xh.jpg
# data\images\id_664s1z4rww.jpg
# data\images\id_fe3rxq4495.jpg
# data\images\id_20lexlrojc.jpg
# data\images\id_z69tezcerd.jpg
# data\images\id_9x09ltbdkc.jpg
# data\images\id_a5y9xgbbvh.jpg
# data\images\id_77yvo7djvx.jpg
# data\images\id_p7gbkw6fac.jpg
# data\images\id_is6qvm3hoj.jpg
# data\images\id_ta824awk8u.jpg
# data\images\id_2wsz8etqq8.jpg
# data\images\id_by6e6shi2z.jpg
# data\images\id_m0kwdfv3n8.jpg
# data\images\id_8daq3g3gjh.jpg
# data\images\id_h0c7f93ooz.jpg
# data\images\id_tvzkxokqed.jpg
# data\images\id_x8jabafqvn.jpg
# data\images\id_9eocbjfxy5.jpg
# data\images\id_uahbj2v0w9.jpg
# data\images\id_e4124p2abl.jpg
# data\images\id_p5cwsp3ed1.jpg
# data\images\id_57a65wb4qc.jpg
# data\images\id_zw3ez6sob0.jpg
# data\images\id_zofc0rww9i.jpg
# data\images\id_3xszhdulod.jpg
# data\images\id_q6m64eu8fz.jpg
# data\images\id_bhxgop8sch.jpg
# data\images\id_qx3tpu72kt.jpg
# data\images\id_jewa1kipr1.jpg
# data\images\id_qx3tpu72kt.jpg
# data\images\id_m0kwdfv3n8.jpg
# data\images\id_bhxgop8sch.jpg
# data\images\id_138trbgjle.jpg
# data\images\id_ui292hgdmi.jpg
# data\images\id_7tgo99b7gy.jpg
# data\images\id_4ff79j4gv4.jpg
# data\images\id_izmmd3tjlj.jpg
# data\images\id_p0uyhf1k5v.jpg
# data\images\id_2phbgf1x5m.jpg
# data\images\id_58rguqh8gv.jpg
# data\images\id_nl5asaffj8.jpg
# data\images\id_8daq3g3gjh.jpg
# data\images\id_mi1fi40efb.jpg
# data\images\id_u2ushq95s3.jpg
# data\images\id_xeuwa8b3u9.jpg
# data\images\id_8aq7cnhtl5.jpg
# data\images\id_tgpg2oujnz.jpg
# data\images\id_8rsxptmxkc.jpg
# data\images\id_jamycww4eq.jpg
# data\images\id_by6e6shi2z.jpg
# data\images\id_sv9q2kedlr.jpg
# data\images\id_nw02fw99a0.jpg
# data\images\id_uc2asw08il.jpg
# data\images\id_beb4eptdn4.jpg
# data\images\id_iutwh8bfqo.jpg
# data\images\id_48165276os.jpg
# data\images\id_1xpbtfb4xh.jpg
# data\images\id_n9alv46e3p.jpg
# data\images\id_jae11mzfte.jpg
# data\images\id_o8l2fgsn7v.jpg
# data\images\id_btfcsd8hls.jpg
# data\images\id_zg9jc73sf7.jpg
# data\images\id_jdell00c1g.jpg
# data\images\id_l12dc0d0er.jpg
# data\images\id_4xe7v3uzb0.jpg
# data\images\id_p90nleszgt.jpg
# data\images\id_tbop9cccoc.jpg
# data\images\id_hp91msxiz1.jpg
# data\images\id_m73mz74z8l.jpg
# data\images\id_9pbj5r74nc.jpg
# data\images\id_3p4w3wcgyz.jpg
# data\images\id_kr733n1tsu.jpg
# data\images\id_v2jm47dges.jpg
# data\images\id_b9qlq9zy3e.jpg
# data\images\id_7yb76jlexx.jpg
# data\images\id_q5zllac1n2.jpg
# data\images\id_4fq8jiwxl0.jpg
# data\images\id_bt2zp2gbmn.jpg
# data\images\id_25tlcquo1x.jpg
# data\images\id_7v191des6a.jpg
# data\images\id_ru4hal0k5c.jpg
# data\images\id_vgp6tq0vsk.jpg
# data\images\id_ivl68a0hxd.jpg
# data\images\id_fmofpxvw0i.jpg
# data\images\id_i20oi7qcal.jpg
# data\images\id_x8jabafqvn.jpg
# data\images\id_spy5q9lu32.jpg
# data\images\id_g53wol4m59.jpg
# data\images\id_gtyf1219br.jpg
# data\images\id_is6qvm3hoj.jpg
# data\images\id_2oltn8avgm.jpg
# data\images\id_bktdwmg4lm.jpg
# data\images\id_tu8mibp371.jpg
# data\images\id_n5talfnmmk.jpg
# data\images\id_m3nl2z99tk.jpg
# data\images\id_rnp8fcintk.jpg
# data\images\id_ktdlh7cwmo.jpg
# data\images\id_tdb81ada4s.jpg
# data\images\id_k31xcsf57u.jpg
# data\images\id_624x39bg9o.jpg
# data\images\id_6nolb218pj.jpg
# data\images\id_d775p5yr30.jpg
# data\images\id_wgvmmkfg6y.jpg
# data\images\id_a2xgyegvl4.jpg
# data\images\id_wczc5k3dwj.jpg
# data\images\id_82q3ero1ss.jpg
# data\images\id_tbop9cccoc.jpg
# data\images\id_muei6t4km6.jpg
# data\images\id_tm9d3cl87f.jpg
# data\images\id_087dra2apu.jpg
# data\images\id_q6m64eu8fz.jpg
# data\images\id_mtpmujtq22.jpg
# data\images\id_iutwh8bfqo.jpg
# data\images\id_nw02fw99a0.jpg
# data\images\id_p0uyhf1k5v.jpg
# data\images\id_3xszhdulod.jpg
# data\images\id_uhbqlk1fm0.jpg
# data\images\id_1xpbtfb4xh.jpg
# data\images\id_021o79u9zs.jpg
# data\images\id_uin77hhkwi.jpg
# data\images\id_23rsmol80e.jpg
# data\images\id_988opam1qk.jpg
# data\images\id_by6e6shi2z.jpg
# data\images\id_lcg2ls6e1w.jpg
# data\images\id_p90nleszgt.jpg
# data\images\id_nw02fw99a0.jpg
# data\images\id_epdgxdr9xf.jpg
# data\images\id_a79vcelxje.jpg
# data\images\id_tkqnlwx1y5.jpg
# data\images\id_7tgo99b7gy.jpg
# data\images\id_5bbz3srksa.jpg
# data\images\id_y8d31sm2om.jpg
# data\images\id_s2jyv2cu50.jpg
# data\images\id_b9i2zz9yug.jpg
# data\images\id_l0tm7il1xn.jpg
# data\images\id_gip2419rqo.jpg
# data\images\id_m52amtpkzq.jpg
# data\images\id_ic7er132w9.jpg
# data\images\id_84nwjhw546.jpg
# data\images\id_cnus6goi8x.jpg
# data\images\id_zh3ynqyzrn.jpg
# data\images\id_of3h00wv6g.jpg
# data\images\id_i1vip0e25k.jpg
# data\images\id_937jmrnd81.jpg
# data\images\id_5bbz3srksa.jpg
# data\images\id_qh4win0bw9.jpg
# data\images\id_79wbipgniy.jpg
# data\images\id_jewa1kipr1.jpg
# data\images\id_7chz2q4dsm.jpg
# data\images\id_5aayt7wk7i.jpg
# data\images\id_b9qlq9zy3e.jpg
# data\images\id_qjmh7o69nh.jpg
# data\images\id_rcmgx74i4g.jpg
# data\images\id_h0c7f93ooz.jpg
# data\images\id_jt20t8uy30.jpg
# data\images\id_cicxy583s3.jpg
# data\images\id_xculy3gzpk.jpg
# data\images\id_4d24j2jv1q.jpg
# data\images\id_xqvc22teyc.jpg
# data\images\id_7chz2q4dsm.jpg
# data\images\id_40jro80u2f.jpg
# data\images\id_v2jm47dges.jpg
# data\images\id_rtri28ktxd.jpg
# data\images\id_xcv8hacv2o.jpg
# data\images\id_7chz2q4dsm.jpg
# data\images\id_bhxgop8sch.jpg
# data\images\id_5e3mzdro2p.jpg
# data\images\id_hbn9jizhwv.jpg
# data\images\id_wczc5k3dwj.jpg
# data\images\id_u2ycfaq5e0.jpg
# data\images\id_d0b50l3j3h.jpg
# data\images\id_xeuwa8b3u9.jpg
# data\images\id_s5ad3dl5v4.jpg
# data\images\id_jiezf5gtsi.jpg
# data\images\id_wq2owxeg15.jpg
# data\images\id_rlc26w9tpp.jpg
# data\images\id_nzkpf8tr8o.jpg
# data\images\id_087dra2apu.jpg
# data\images\id_rsb2v3qu20.jpg
# data\images\id_f17wgaoouo.jpg
# data\images\id_j1hoshe71a.jpg
# data\images\id_wfijblgppj.jpg
# data\images\id_njgy63grdy.jpg
# data\images\id_lc05xjrwua.jpg
# data\images\id_y1be61kpy1.jpg
# data\images\id_w01gu00ojz.jpg
# data\images\id_e7ctpfkatp.jpg
# data\images\id_3rrbg84f29.jpg
# data\images\id_1esqqvsjvk.jpg
# data\images\id_4d24j2jv1q.jpg
# data\images\id_hw550kq3v2.jpg
# data\images\id_vukb9kjcto.jpg
# data\images\id_n9bbcos7p2.jpg
# data\images\id_5r1k5g43dg.jpg
# data\images\id_x8jabafqvn.jpg
# data\images\id_r90wmxlo7g.jpg
# data\images\id_9f1y6j5b9d.jpg
# data\images\id_c86b3blpzi.jpg
# data\images\id_c69tm8y0y2.jpg
# data\images\id_kr733n1tsu.jpg
# data\images\id_8ki9psqzdy.jpg
# data\images\id_ojyxvwz9ej.jpg
# data\images\id_6ujuefpy4m.jpg
# data\images\id_ib4bkb6uto.jpg
# data\images\id_n5talfnmmk.jpg
# data\images\id_jqbclo5yeq.jpg
# data\images\id_bilucrhgg3.jpg
# data\images\id_ic7er132w9.jpg
# data\images\id_mo2v2kgx60.jpg
# data\images\id_s2jyv2cu50.jpg
# data\images\id_33a4icf8ni.jpg
# data\images\id_7r4idjxs41.jpg
# data\images\id_ks29w27js0.jpg
# data\images\id_mty3c1iqq1.jpg
# data\images\id_w91m8fnf8f.jpg
# data\images\id_p0uyhf1k5v.jpg
# data\images\id_s15z5p4sev.jpg
# data\images\id_e7v9ytlskr.jpg
# data\images\id_4qc0qxu5oh.jpg
# data\images\id_gc9l837nw2.jpg
# data\images\id_is6qvm3hoj.jpg
# data\images\id_wqn3kwf0zq.jpg
# data\images\id_ng8eif5a91.jpg
# data\images\id_g2qoimboyc.jpg
# data\images\id_6qr9x3f384.jpg
# data\images\id_7ayy2uh8ya.jpg
# data\images\id_w1dk4h5p4w.jpg
# data\images\id_tzsjd9livd.jpg
# data\images\id_p6omtmwcl1.jpg
# data\images\id_uv8zibyt2l.jpg
# data\images\id_et97dmccl6.jpg
# data\images\id_runfzrtfcb.jpg
# data\images\id_1c9bm6vnzq.jpg
# data\images\id_lq3n07hf7o.jpg
# data\images\id_iecoe7yawd.jpg
# data\images\id_99802d15ky.jpg
# data\images\id_7r4idjxs41.jpg
# data\images\id_1gibtfi2n8.jpg
# data\images\id_ohdqwwlnpv.jpg
# data\images\id_fu682pu2sa.jpg
# data\images\id_i5pp8c0zob.jpg
# data\images\id_cilsouekou.jpg
# data\images\id_nw02fw99a0.jpg
# data\images\id_l90j3qhlpz.jpg
# data\images\id_ta824awk8u.jpg
# data\images\id_eventkcmpa.jpg
# data\images\id_cg82fmj278.jpg
# data\images\id_8daq3g3gjh.jpg
# data\images\id_tlotno93zp.jpg
# data\images\id_jrppxrh1it.jpg
# data\images\id_9x09ltbdkc.jpg
# data\images\id_15rb0dgq66.jpg
# data\images\id_n24hk0g8lw.jpg
# data\images\id_tbop9cccoc.jpg
# data\images\id_yvsh2v76mf.jpg
# data\images\id_bf5z9bx9xf.jpg
# data\images\id_tbop9cccoc.jpg
# data\images\id_ysi2242k6l.jpg
# data\images\id_tmtzoe9bns.jpg
# data\images\id_331urb6uko.jpg
# data\images\id_tuiwsxil2e.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_wd51nh9072.jpg
# data\images\id_a5y9xgbbvh.jpg
# data\images\id_9eocbjfxy5.jpg
# data\images\id_ch6r0g46fr.jpg
# data\images\id_og5x0uny64.jpg
# data\images\id_xyf205iv7p.jpg
# data\images\id_nv366dqhx7.jpg
# data\images\id_pms9qxpoz3.jpg
# data\images\id_mkpnrd5p32.jpg
# data\images\id_xyf205iv7p.jpg
# data\images\id_jl93f5rtzc.jpg
# data\images\id_82q3ero1ss.jpg
# data\images\id_nrikbmlefy.jpg
# data\images\id_ga85pu6228.jpg
# data\images\id_0y7wuu76bp.jpg
# data\images\id_44y9vdc3r8.jpg
# data\images\id_q7l2awwq7g.jpg
# data\images\id_4y1b6jhgue.jpg
# data\images\id_epdgxdr9xf.jpg
# data\images\id_5bbz3srksa.jpg
# data\images\id_f1532fixpr.jpg
# data\images\id_zh3ynqyzrn.jpg
# data\images\id_wbxjec4uq4.jpg
# data\images\id_zvx3olbgqg.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_h005elaguq.jpg
# data\images\id_86a2zngtjy.jpg
# data\images\id_nw02fw99a0.jpg
# data\images\id_4vwgs6al82.jpg
# data\images\id_cgyn1ix1ld.jpg
# data\images\id_86a2zngtjy.jpg
# data\images\id_ixxqgodncy.jpg
# data\images\id_v0av0bx5ua.jpg
# data\images\id_qkz8b1sany.jpg
# data\images\id_vxfv34g53d.jpg
# data\images\id_pms9qxpoz3.jpg
# data\images\id_dkskb44yb6.jpg
# data\images\id_gg9tm95uib.jpg
# data\images\id_by6e6shi2z.jpg
# data\images\id_90egdm0iiy.jpg
# data\images\id_o8adhibofv.jpg
# data\images\id_7wk6y42ce8.jpg
# data\images\id_ns0ww9t3ju.jpg
# data\images\id_7yb76jlexx.jpg
# data\images\id_s2jyv2cu50.jpg
# data\images\id_c9zfocph2k.jpg
# data\images\id_nk6b8hdvu3.jpg
# data\images\id_eldxg2drqi.jpg
# data\images\id_7chz2q4dsm.jpg
# data\images\id_9pbj5r74nc.jpg
# data\images\id_a4dlrgudtn.jpg
# data\images\id_iutwh8bfqo.jpg
# data\images\id_nw02fw99a0.jpg
# data\images\id_um5sxszvdq.jpg
# data\images\id_sh5w9551z9.jpg
# data\images\id_9qtfjptkch.jpg
# data\images\id_mpmt3ysro0.jpg
# data\images\id_bvht7rqdqs.jpg
# data\images\id_az75itcgjz.jpg
# data\images\id_ipmba1040m.jpg
# data\images\id_kjtfw1vgg1.jpg
# data\images\id_48165276os.jpg
# data\images\id_snvsv2gtao.jpg
# data\images\id_3m4qh3fisx.jpg
# data\images\id_j80khun6jy.jpg
# data\images\id_sp3aywnevu.jpg
# data\images\id_jl93f5rtzc.jpg
# data\images\id_lxgubdmeak.jpg
# data\images\id_9pbj5r74nc.jpg
# data\images\id_kr733n1tsu.jpg
# data\images\id_0qejp3o0q3.jpg
# data\images\id_4y1b6jhgue.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_pqzhdlyuu1.jpg
# data\images\id_1gsflyazao.jpg
# data\images\id_dvq8cek8pf.jpg
# data\images\id_yqip573e9t.jpg
# data\images\id_k31xcsf57u.jpg
# data\images\id_auct5p9tzd.jpg
# data\images\id_qcgac2hzwm.jpg
# data\images\id_fzogq9kijh.jpg
# data\images\id_e7y0uo9taq.jpg
# data\images\id_le5mwhewfl.jpg
# data\images\id_qltslzihpq.jpg
# data\images\id_vayi564v9k.jpg
# data\images\id_g9tqpcbr7y.jpg
# data\images\id_664s1z4rww.jpg
# data\images\id_mrn2bbogx3.jpg
# data\images\id_4qc0qxu5oh.jpg
# data\images\id_r7rcvu1zc8.jpg
# data\images\id_jqcv32ajje.jpg
# data\images\id_2wsz8etqq8.jpg
# data\images\id_au0abzw8wd.jpg
# data\images\id_rqj8je0h6p.jpg
# data\images\id_xcv8hacv2o.jpg
# data\images\id_bd6gm5l5m1.jpg
# data\images\id_wd51nh9072.jpg
# data\images\id_crenkaw87t.jpg
# data\images\id_djivwejlfp.jpg
# data\images\id_d3rjv7rlle.jpg
# data\images\id_t22c0x2s85.jpg
# data\images\id_zke3pmbsw3.jpg
# data\images\id_mahz3x8yer.jpg
# data\images\id_p6omtmwcl1.jpg
# data\images\id_xtl771qwo0.jpg
# data\images\id_v51xobxvyk.jpg
# data\images\id_wd51nh9072.jpg
# data\images\id_624x39bg9o.jpg
# data\images\id_23rsmol80e.jpg
# data\images\id_syl8z4yeda.jpg
# data\images\id_wus57zro6l.jpg
# data\images\id_dkskb44yb6.jpg
# data\images\id_tzsjd9livd.jpg
# data\images\id_ks4su5m3hj.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_f1532fixpr.jpg
# data\images\id_bvaau1zc3d.jpg
# data\images\id_warx3mh4mf.jpg
# data\images\id_tmtzoe9bns.jpg
# data\images\id_zbnnf2a6el.jpg
# data\images\id_pnave1opt9.jpg
# data\images\id_dqs7gwi0lc.jpg
# data\images\id_njgy63grdy.jpg
# data\images\id_z0i61ad0tq.jpg
# data\images\id_34bm0uo95m.jpg
# data\images\id_87rt6lehbn.jpg
# data\images\id_bw8mq2lrsq.jpg
# data\images\id_qw2jgodk5m.jpg
# data\images\id_um5sxszvdq.jpg
# data\images\id_v7a1nqldvn.jpg
# data\images\id_7n0g3j6gzk.jpg
# data\images\id_dfvwtupp8l.jpg
# data\images\id_jpe9ujl5qm.jpg
# data\images\id_r7rcvu1zc8.jpg
# data\images\id_m3k4pmmra6.jpg
# data\images\id_1zdxw0y038.jpg
# data\images\id_qa70t0m4yc.jpg
# data\images\id_w0k3muljqb.jpg
# data\images\id_7tayaxpbyp.jpg
# data\images\id_042y6d5xok.jpg
# data\images\id_l0yddk6zes.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_f7dzlbfp75.jpg
# data\images\id_iisyobbs2a.jpg
# data\images\id_md6hbufvqv.jpg
# data\images\id_4r9yajci0x.jpg
# data\images\id_hbviida8th.jpg
# data\images\id_bvht7rqdqs.jpg
# data\images\id_v0av0bx5ua.jpg
# data\images\id_bhydrok4am.jpg
# data\images\id_2s7rdefjuk.jpg
# data\images\id_ng9b37pjh8.jpg
# data\images\id_jaqfrsv1ll.jpg
# data\images\id_1dx2k1l72r.jpg
# data\images\id_8j285ahjck.jpg
# data\images\id_ng9b37pjh8.jpg
# data\images\id_tifbx6v6di.jpg
# data\images\id_lwf47cz8f3.jpg
# data\images\id_afv626iamx.jpg
# data\images\id_cn2wq4vf4s.jpg
# data\images\id_mpmt3ysro0.jpg
# data\images\id_d5zx81l4cf.jpg
# data\images\id_is6qvm3hoj.jpg
# data\images\id_ch6r0g46fr.jpg
# data\images\id_ctkvvkc84k.jpg
# data\images\id_nl3aeas2wu.jpg
# data\images\id_zk5f24dvrh.jpg
# data\images\id_hdpzuf5maf.jpg
# data\images\id_afv626iamx.jpg
# data\images\id_bs0z86wm00.jpg
# data\images\id_nk6b8hdvu3.jpg
# data\images\id_i5pp8c0zob.jpg
# data\images\id_afv626iamx.jpg
# data\images\id_8x0h7f3orn.jpg
# data\images\id_io6mu601ef.jpg
# data\images\id_l90j3qhlpz.jpg
# data\images\id_u1mvhmutq3.jpg
# data\images\id_331urb6uko.jpg
# data\images\id_tl2d67i3vy.jpg
# data\images\id_yxd1bn2bnt.jpg
# data\images\id_rnp8fcintk.jpg
# data\images\id_bsajd1gy4y.jpg
# data\images\id_g9tqpcbr7y.jpg
# data\images\id_gj632pfurw.jpg
# data\images\id_9x09ltbdkc.jpg
# data\images\id_8ixgyugm6f.jpg
# data\images\id_qa70t0m4yc.jpg
# data\images\id_qa70t0m4yc.jpg
# data\images\id_2oltn8avgm.jpg
# data\images\id_331urb6uko.jpg
# data\images\id_auct5p9tzd.jpg
# data\images\id_57a65wb4qc.jpg
# data\images\id_b9qlq9zy3e.jpg
# data\images\id_p90nleszgt.jpg
# data\images\id_80fx2htafa.jpg
# data\images\id_o5gznb9nvm.jpg
# data\images\id_n0dqkovtp3.jpg
# data\images\id_e7y0uo9taq.jpg
# data\images\id_ur73wn6b2v.jpg
# data\images\id_tu8mibp371.jpg
# data\images\id_epdgxdr9xf.jpg
# data\images\id_yzhkb0zf37.jpg
# data\images\id_fa626uztwq.jpg
# data\images\id_8x0h7f3orn.jpg
# data\images\id_wf4us8fhib.jpg
# data\images\id_bkc1sypwhe.jpg
# data\images\id_6o6am6gf0i.jpg
# data\images\id_vkasft3kl4.jpg
# data\images\id_tna29yexxm.jpg
# data\images\id_ta824awk8u.jpg
# data\images\id_1g71f8npmo.jpg
# data\images\id_xc49qafwkt.jpg
# data\images\id_noluf8agf5.jpg
# data\images\id_aa5go0vd7g.jpg
# data\images\id_fzogq9kijh.jpg
# data\images\id_6kboq7k8e0.jpg
# data\images\id_z0i61ad0tq.jpg
# data\images\id_cgccsf7xyt.jpg
# data\images\id_ndhdv3wuvg.jpg
# data\images\id_18zr61kc0a.jpg
# data\images\id_9f1y6j5b9d.jpg
# data\images\id_va4z1ugq2d.jpg
# data\images\id_a2myf5oy8r.jpg
# data\images\id_zey0sdkbta.jpg
# data\images\id_pwiv4czvne.jpg
# data\images\id_h0c7f93ooz.jpg
# data\images\id_2f96ugnp7h.jpg
# data\images\id_ph5yzye70t.jpg
# data\images\id_wc1se79we4.jpg
# data\images\id_y1be61kpy1.jpg
# data\images\id_4y1b6jhgue.jpg
# data\images\id_2fk6cyep6k.jpg
# data\images\id_xahnp3wxin.jpg
# data\images\id_ecq3iqw0g7.jpg
# data\images\id_a5nf4ezn3v.jpg
# data\images\id_wd51nh9072.jpg
# data\images\id_tf4ojblzfw.jpg
# data\images\id_twaz7o240a.jpg
# data\images\id_3e24re5ruz.jpg
# data\images\id_147gpcegp6.jpg
# data\images\id_no9tx04ly6.jpg
# data\images\id_1a6j7t0nuk.jpg
# data\images\id_l0tm7il1xn.jpg
# data\images\id_ucb98pn416.jpg
# data\images\id_n2p8hhg5y0.jpg
# data\images\id_sin11o52ho.jpg
# data\images\id_1cvkxwzx4d.jpg
# data\images\id_jamycww4eq.jpg
# data\images\id_5dkxygfay2.jpg
# data\images\id_l0yddk6zes.jpg
# data\images\id_g8307c6ymr.jpg
# data\images\id_stsa6kt4zg.jpg
# data\images\id_1xpbtfb4xh.jpg
# data\images\id_iv1edp9fei.jpg
# data\images\id_bejugd5hv6.jpg
# data\images\id_cn2wq4vf4s.jpg
# data\images\id_cn2wq4vf4s.jpg
# data\images\id_pqzhdlyuu1.jpg
# data\images\id_5aayt7wk7i.jpg
# data\images\id_jh6051zrho.jpg
# data\images\id_tgqn7f4tx0.jpg
# data\images\id_hpkgp7d6gt.jpg
# data\images\id_nvvwr0mhdk.jpg
# data\images\id_90t410ke2y.jpg
# data\images\id_mpmt3ysro0.jpg
# data\images\id_sagntmxcpy.jpg
# data\images\id_o6eyzd4i8a.jpg
# data\images\id_of3h00wv6g.jpg
# data\images\id_7fv766z6w1.jpg
# data\images\id_8ixgyugm6f.jpg
# data\images\id_rqr7ifphi8.jpg
# data\images\id_qi0ff7w9eo.jpg
# data\images\id_xeuwa8b3u9.jpg
# data\images\id_d1g42czqeh.jpg
# data\images\id_x7nd051hom.jpg
# data\images\id_g2qoimboyc.jpg
# data\images\id_95xdw4rbzb.jpg
# data\images\id_jewa1kipr1.jpg
# data\images\id_au0abzw8wd.jpg
# data\images\id_b1cv4zcozi.jpg
# data\images\id_beb4eptdn4.jpg
# data\images\id_j1i93ltxls.jpg
# data\images\id_mkpnrd5p32.jpg
# data\images\id_tvzkxokqed.jpg
# data\images\id_j8foptaf6f.jpg
# data\images\id_8daq3g3gjh.jpg
# data\images\id_0de37ox1bm.jpg
# data\images\id_84nwjhw546.jpg
# data\images\id_pctj4za5je.jpg
# data\images\id_6r4u8vcjay.jpg
# data\images\id_8x0h7f3orn.jpg
# data\images\id_ztgh8qmu65.jpg
# data\images\id_muei6t4km6.jpg
# data\images\id_wbxjec4uq4.jpg
# data\images\id_zrs3jxiyuh.jpg
# data\images\id_dv8w9xzrvu.jpg
# data\images\id_dyztcaf9yg.jpg
# data\images\id_qg95y3rm5q.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_8ztw2t9cet.jpg
# data\images\id_z0i61ad0tq.jpg
# data\images\id_hw550kq3v2.jpg
# data\images\id_fn9duuohc1.jpg
# data\images\id_no9tx04ly6.jpg
# data\images\id_wij48tbsif.jpg
# data\images\id_yd3tmwvvgu.jpg
# data\images\id_1g71f8npmo.jpg
# data\images\id_i5pp8c0zob.jpg
# data\images\id_dtffc5i3ry.jpg
# data\images\id_okapnkihwo.jpg
# data\images\id_y87srhljbk.jpg
# data\images\id_77yvo7djvx.jpg
# data\images\id_bhxgop8sch.jpg
# data\images\id_vh0k3szcjh.jpg
# data\images\id_wy64v158ve.jpg
# data\images\id_e3tep47339.jpg
# data\images\id_43cevf8y4e.jpg
# data\images\id_7tgo99b7gy.jpg
# data\images\id_kemmb57ure.jpg
# data\images\id_qk46xf80l5.jpg
# data\images\id_ks4su5m3hj.jpg
# data\images\id_fu682pu2sa.jpg
# data\images\id_stsa6kt4zg.jpg
# data\images\id_5d1f8lzju3.jpg
# data\images\id_pb9amtm9hk.jpg
# data\images\id_cruxs39gz0.jpg
# data\images\id_epdgxdr9xf.jpg
# data\images\id_x85na3swoi.jpg
# data\images\id_77yvo7djvx.jpg
# data\images\id_9c48ivvo8u.jpg
# data\images\id_l90j3qhlpz.jpg
# data\images\id_7tgo99b7gy.jpg
# data\images\id_d1g42czqeh.jpg
# data\images\id_o0s626fwo8.jpg
# data\images\id_tdb81ada4s.jpg
# data\images\id_dwu57mgtcb.jpg
# data\images\id_ajzbqyf67p.jpg
# data\images\id_ezd6x40fd0.jpg
# data\images\id_v2jm47dges.jpg
# data\images\id_mkpnrd5p32.jpg
# data\images\id_warx3mh4mf.jpg
# data\images\id_sagntmxcpy.jpg
# data\images\id_x7nd051hom.jpg
# data\images\id_r1awdf8bxw.jpg
# data\images\id_u7424e0jbz.jpg
# data\images\id_xa3mozz6v6.jpg
# data\images\id_n24hk0g8lw.jpg
# data\images\id_99dqny1a0l.jpg
# data\images\id_ecq3iqw0g7.jpg
# data\images\id_p2kuzgnz1b.jpg
# data\images\id_9neerla9dn.jpg
# data\images\id_6qr9x3f384.jpg
# data\images\id_btfcsd8hls.jpg
# data\images\id_lrvvhpbhka.jpg
# data\images\id_ng8eif5a91.jpg
# data\images\id_8rsxptmxkc.jpg
# data\images\id_t22c0x2s85.jpg
# data\images\id_0pex8jec2z.jpg
# data\images\id_k4ly4467l9.jpg
# data\images\id_ks4su5m3hj.jpg
# data\images\id_uea1p68x2j.jpg
# data\images\id_6fbhkyv1rd.jpg
# data\images\id_q5oduazlas.jpg
# data\images\id_wfijblgppj.jpg
# data\images\id_qkz8b1sany.jpg
# data\images\id_5bbz3srksa.jpg
# data\images\id_ml7s0vyb5x.jpg
# data\images\id_dn3ulndjff.jpg
# data\images\id_90egdm0iiy.jpg
# data\images\id_tf1w8yeuoo.jpg
# data\images\id_a0t3sx8hn0.jpg
# data\images\id_j65mnvpevk.jpg
# data\images\id_gdd24yvc23.jpg
# data\images\id_uafh5h1w2z.jpg
# data\images\id_bt2zp2gbmn.jpg
# data\images\id_xeuwa8b3u9.jpg
# data\images\id_bejugd5hv6.jpg
# data\images\id_bj4v8tg4n3.jpg
# data\images\id_4cgsb6hlt0.jpg
# data\images\id_li63u65zdf.jpg
# data\images\id_ipmba1040m.jpg
# data\images\id_2wsz8etqq8.jpg
# data\images\id_qqzjbyaaff.jpg
# data\images\id_ilmjjeqpcy.jpg
# data\images\id_4qta0i8drs.jpg
# data\images\id_wmytvl7d4d.jpg
# data\images\id_btfcsd8hls.jpg
# data\images\id_5mtjl379ep.jpg
# data\images\id_39kolpd9ds.jpg
# data\images\id_2phbgf1x5m.jpg
# data\images\id_hxh24buc7k.jpg
# data\images\id_9d0jjtbefc.jpg
# data\images\id_cruxs39gz0.jpg
# data\images\id_pn6iyrdqqz.jpg
# data\images\id_5aayt7wk7i.jpg
# data\images\id_4y1b6jhgue.jpg
# data\images\id_fzak256l5q.jpg
# data\images\id_cgyn1ix1ld.jpg
# data\images\id_6y8h3f87d9.jpg
# data\images\id_e5cvk28krq.jpg
# data\images\id_bktdwmg4lm.jpg
# data\images\id_y8d31sm2om.jpg
# data\images\id_ng9b37pjh8.jpg
# data\images\id_rm8d1zznhz.jpg
# data\images\id_0fdars2kkw.jpg
# data\images\id_bq3qp0cuw2.jpg
# data\images\id_7g7lj99tg4.jpg
# data\images\id_ta824awk8u.jpg
# data\images\id_m73mz74z8l.jpg
# data\images\id_yfgqifa1av.jpg
# data\images\id_i7nitsscaw.jpg
# data\images\id_h5p5jtx9x5.jpg
# data\images\id_4svm2mbojb.jpg
# data\images\id_nrigd8iz8k.jpg
# data\images\id_r1awdf8bxw.jpg
# data\images\id_z0jvwikzzn.jpg
# data\images\id_2v40bfhybf.jpg
# data\images\id_u5cxqsylou.jpg
# data\images\id_j6yric3kmj.jpg
# data\images\id_22hbp9nu1d.jpg
# data\images\id_5bbz3srksa.jpg
# data\images\id_ru4hal0k5c.jpg
# data\images\id_ysi2242k6l.jpg
# data\images\id_6bqoiceoxx.jpg
# data\images\id_pn6iyrdqqz.jpg
# data\images\id_23rsmol80e.jpg
# data\images\id_7wk6y42ce8.jpg
# data\images\id_xculy3gzpk.jpg
# data\images\id_mialolbp52.jpg
# data\images\id_wmni25iax5.jpg
# data\images\id_u68vnc3ig8.jpg
# data\images\id_ilmjjeqpcy.jpg
# data\images\id_auct5p9tzd.jpg
# data\images\id_iohrjcek7i.jpg
# data\images\id_kbanzvtryi.jpg
# data\images\id_8daq3g3gjh.jpg
# data\images\id_vh0k3szcjh.jpg
# data\images\id_66g6mwyqq1.jpg
# data\images\id_kgvspp0gry.jpg
# data\images\id_8ksz34ssgs.jpg
# data\images\id_5udrklg7is.jpg
# data\images\id_23rsmol80e.jpg
# data\images\id_19lavqwwve.jpg
# data\images\id_i1vip0e25k.jpg
# data\images\id_sxovmjvddp.jpg
# data\images\id_nw02fw99a0.jpg
# data\images\id_2gp13u7qvy.jpg
# data\images\id_r1h52tth8l.jpg
# data\images\id_ajzbqyf67p.jpg
# data\images\id_sin11o52ho.jpg
# data\images\id_tke5283vm6.jpg
# data\images\id_l0yddk6zes.jpg
# data\images\id_qk46xf80l5.jpg
# data\images\id_jo8uyjrgbt.jpg
# data\images\id_9ctex4nrc1.jpg
# data\images\id_m3nl2z99tk.jpg
# data\images\id_uahbj2v0w9.jpg
# data\images\id_tl2d67i3vy.jpg
# data\images\id_dqs7gwi0lc.jpg
# data\images\id_jsow1t087p.jpg
# data\images\id_zofc0rww9i.jpg
# data\images\id_4ff79j4gv4.jpg
# data\images\id_o5828e4afd.jpg
# data\images\id_a36aomg01d.jpg
# data\images\id_bhydrok4am.jpg
# data\images\id_1g71f8npmo.jpg
# data\images\id_v7a1nqldvn.jpg
# data\images\id_n0dqkovtp3.jpg
# data\images\id_1i2c98t2s2.jpg
# data\images\id_x7xw4fzomb.jpg
# data\images\id_qg95y3rm5q.jpg
# data\images\id_yvysltliu6.jpg
# data\images\id_15keeum3u3.jpg
# data\images\id_fqz06epe0k.jpg
# data\images\id_4vwgs6al82.jpg
# data\images\id_n0dqkovtp3.jpg
# data\images\id_8u5ihtwvz1.jpg
# data\images\id_ghzma8epx3.jpg
# data\images\id_tu8mibp371.jpg
# data\images\id_i7nitsscaw.jpg
# data\images\id_9pbj5r74nc.jpg
# data\images\id_epdgxdr9xf.jpg
# data\images\id_frahdlz5n3.jpg
# data\images\id_a9ioxxzr7b.jpg
# data\images\id_z8zg282t55.jpg
# data\images\id_p9klvnbrqa.jpg
# data\images\id_6x6jk4x7p8.jpg
# data\images\id_jo8uyjrgbt.jpg
# data\images\id_1ziracu5s5.jpg
# data\images\id_tgqn7f4tx0.jpg
# data\images\id_i7k81h7ycw.jpg
# data\images\id_zg9jc73sf7.jpg
# data\images\id_nbamhn8mgn.jpg
# data\images\id_4qta0i8drs.jpg
# data\images\id_pqzhdlyuu1.jpg
# data\images\id_5rwv5nd2tq.jpg
# data\images\id_e7y0uo9taq.jpg
# data\images\id_zk5f24dvrh.jpg
# data\images\id_nk6b8hdvu3.jpg
# data\images\id_cgyn1ix1ld.jpg
# data\images\id_i7nitsscaw.jpg
# data\images\id_ir4jvv7haa.jpg
# data\images\id_b3jty66mjo.jpg
# data\images\id_3l42ck1ho6.jpg
# data\images\id_rjjkcsmkbh.jpg
# data\images\id_4qc0qxu5oh.jpg
# data\images\id_4sawx3kbqd.jpg
# data\images\id_jt0roeq9yt.jpg
# data\images\id_vvcixbrht6.jpg
# data\images\id_1qq01s8e5q.jpg
# data\images\id_g2sqqzfmua.jpg
# data\images\id_42hocdouyp.jpg
# data\images\id_ezd6x40fd0.jpg
# data\images\id_i7k81h7ycw.jpg
# data\images\id_3vtq93cpm1.jpg
# data\images\id_a1jdwsbpyl.jpg
# data\images\id_zp4mfxd55p.jpg
# data\images\id_4y1b6jhgue.jpg
# data\images\id_xaw1ocymzh.jpg
# data\images\id_auct5p9tzd.jpg
# data\images\id_1o2oc7fqs8.jpg
# data\images\id_w01gu00ojz.jpg
# data\images\id_423v40dw2w.jpg
# data\images\id_mkpnrd5p32.jpg
# data\images\id_m0kwdfv3n8.jpg
# data\images\id_vqxavxbgqv.jpg
# data\images\id_u1mvhmutq3.jpg
# data\images\id_k061rd9uty.jpg
# data\images\id_bba8stn84o.jpg
# data\images\id_tvzkxokqed.jpg
# data\images\id_nw02fw99a0.jpg
# data\images\id_6qr9x3f384.jpg
# data\images\id_by6e6shi2z.jpg
# data\images\id_ch6r0g46fr.jpg
# data\images\id_vmj225uyxh.jpg
# data\images\id_d15oygh6d0.jpg
# data\images\id_4vwgs6al82.jpg
# data\images\id_20lexlrojc.jpg
# data\images\id_906gshebg5.jpg
# data\images\id_xyz1j6qrxt.jpg
# data\images\id_6vvr4khx3u.jpg
# data\images\id_r7rcvu1zc8.jpg
# data\images\id_9pbj5r74nc.jpg
# data\images\id_i0sssks1lo.jpg
# data\images\id_4zywetm95o.jpg
# data\images\id_pqgmfk87uh.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_m2ibf6zkn9.jpg
# data\images\id_uahbj2v0w9.jpg
# data\images\id_auct5p9tzd.jpg
# data\images\id_wr1bsozdoh.jpg
# data\images\id_xb7ir0ifz7.jpg
# data\images\id_ssc5cizh06.jpg
# data\images\id_og5x0uny64.jpg
# data\images\id_7z4kmeq9c7.jpg
# data\images\id_311b3ld96p.jpg
# data\images\id_331urb6uko.jpg
# data\images\id_womj1xex2p.jpg
# data\images\id_tuiwsxil2e.jpg
# data\images\id_e1dww3um75.jpg
# data\images\id_5gudsszz0t.jpg
# data\images\id_7tgo99b7gy.jpg
# data\images\id_1esqqvsjvk.jpg
# data\images\id_mbr5v2sscr.jpg
# data\images\id_u5cxqsylou.jpg
# data\images\id_jl93f5rtzc.jpg
# data\images\id_bhydrok4am.jpg
# data\images\id_syl8z4yeda.jpg
# data\images\id_nw02fw99a0.jpg
# data\images\id_p2kuzgnz1b.jpg
# data\images\id_7yurhvqp72.jpg
# data\images\id_ndhdv3wuvg.jpg
# data\images\id_cgyn1ix1ld.jpg
# data\images\id_j80khun6jy.jpg
# data\images\id_go7ph4k7a1.jpg
# data\images\id_9z6ajhl5wl.jpg
# data\images\id_re74wr6nyy.jpg
# data\images\id_f8hkv2boj5.jpg
# data\images\id_iwm2km59xp.jpg
# data\images\id_jqcv32ajje.jpg
# data\images\id_m2ibf6zkn9.jpg
# data\images\id_4wkzpeu6or.jpg
# data\images\id_hp91msxiz1.jpg
# data\images\id_ni84jbmadv.jpg
# data\images\id_zoa6mk680j.jpg
# data\images\id_q5oduazlas.jpg
# data\images\id_io6mu601ef.jpg
# data\images\id_vmn1yepcxy.jpg
# data\images\id_7g7lj99tg4.jpg
# data\images\id_8x0h7f3orn.jpg
# data\images\id_qk46xf80l5.jpg
# data\images\id_6r4u8vcjay.jpg
# data\images\id_ezd6x40fd0.jpg
# data\images\id_ssc5cizh06.jpg
# data\images\id_8ki9psqzdy.jpg
# data\images\id_hbn9jizhwv.jpg
# data\images\id_is6qvm3hoj.jpg
# data\images\id_15rb0dgq66.jpg
# data\images\id_2aztwqu09t.jpg
# data\images\id_p1z8i43g1e.jpg
# data\images\id_43cevf8y4e.jpg
# data\images\id_mwq9isyl2m.jpg
# data\images\id_vodziadklf.jpg
# data\images\id_sho4od6kye.jpg
# data\images\id_dny0rwnv1d.jpg
# data\images\id_rnjgrvrhj4.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_l7x18hhzkw.jpg
# data\images\id_ic7er132w9.jpg
# data\images\id_exyy777j5h.jpg
# data\images\id_rnp8fcintk.jpg
# data\images\id_oqzfsk3k6v.jpg
# data\images\id_ysi2242k6l.jpg
# data\images\id_4cgsb6hlt0.jpg
# data\images\id_vq09s9hrah.jpg
# data\images\id_qyunwtmja4.jpg
# data\images\id_gsazi483u2.jpg
# data\images\id_f1532fixpr.jpg
# data\images\id_rqs82d32qh.jpg
# data\images\id_mfcxc19oba.jpg
# data\images\id_8jlhuhhu5y.jpg
# data\images\id_1c93ihgovo.jpg
# data\images\id_nfscssxd2u.jpg
# data\images\id_wxwqqxihii.jpg
# data\images\id_5yazfoieuu.jpg
# data\images\id_9cpyomw8az.jpg
# data\images\id_tdb81ada4s.jpg
# data\images\id_a1jdwsbpyl.jpg
# data\images\id_p1z8i43g1e.jpg
# data\images\id_ysi2242k6l.jpg
# data\images\id_a4dlrgudtn.jpg
# data\images\id_86a2zngtjy.jpg
# data\images\id_obvyvrbfoa.jpg
# data\images\id_8ken1mdqby.jpg
# data\images\id_bqs4luq4kl.jpg
# data\images\id_a5nf4ezn3v.jpg
# data\images\id_q7l2awwq7g.jpg
# data\images\id_lvd73frjuz.jpg
# data\images\id_cc2lcr49xv.jpg
# data\images\id_l90j3qhlpz.jpg
# data\images\id_2fnkrnht1g.jpg
# data\images\id_upkon5lrf2.jpg
# data\images\id_22hbp9nu1d.jpg
# data\images\id_zp4mfxd55p.jpg
# data\images\id_zrs3jxiyuh.jpg
# data\images\id_gip2419rqo.jpg
# data\images\id_n5talfnmmk.jpg
# data\images\id_gg9tm95uib.jpg
# data\images\id_w0soultvmf.jpg
# data\images\id_8u5ihtwvz1.jpg
# data\images\id_ks4su5m3hj.jpg
# data\images\id_wqn3kwf0zq.jpg
# data\images\id_a4dlrgudtn.jpg
# data\images\id_021o79u9zs.jpg
# data\images\id_9b0xsy1aba.jpg
# data\images\id_egu5f4y1bu.jpg
# data\images\id_9t9vkxsw2v.jpg
# data\images\id_wus57zro6l.jpg
# data\images\id_2syrsh98me.jpg
# data\images\id_crenkaw87t.jpg
# data\images\id_k061rd9uty.jpg
# data\images\id_warx3mh4mf.jpg
# data\images\id_uxekpj58sj.jpg
# data\images\id_3xidcn77dw.jpg
# data\images\id_5bbz3srksa.jpg
# data\images\id_wxaxv22nhy.jpg
# data\images\id_crenkaw87t.jpg
# data\images\id_nw02fw99a0.jpg
# data\images\id_8ixgyugm6f.jpg
# data\images\id_bilucrhgg3.jpg
# data\images\id_ng9b37pjh8.jpg
# data\images\id_p7gbkw6fac.jpg
# data\images\id_wp2hqrl4ek.jpg
# data\images\id_qf2vlzrh87.jpg
# data\images\id_8daq3g3gjh.jpg
# data\images\id_79wbipgniy.jpg
# data\images\id_1g71f8npmo.jpg
# data\images\id_6nolb218pj.jpg
# data\images\id_z0i61ad0tq.jpg
# data\images\id_ezd6x40fd0.jpg
# data\images\id_p1z8i43g1e.jpg
# data\images\id_ajetqytbnc.jpg
# data\images\id_2p2dyhdw1h.jpg
# data\images\id_jcknbsf9nz.jpg
# data\images\id_nrk5dgk4z9.jpg
# data\images\id_ecq3iqw0g7.jpg
# data\images\id_zvx3olbgqg.jpg
# data\images\id_bf5z9bx9xf.jpg
# data\images\id_8l8zssuabc.jpg
# data\images\id_xcv8hacv2o.jpg
# data\images\id_pms9qxpoz3.jpg
# data\images\id_3jmeoadh9p.jpg
# data\images\id_6o6am6gf0i.jpg
# data\images\id_uahbj2v0w9.jpg
# data\images\id_j80khun6jy.jpg
# data\images\id_qidlol8rix.jpg
# data\images\id_4d24j2jv1q.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_xrb30hnane.jpg
# data\images\id_zrbxgpxuta.jpg
# data\images\id_ga85pu6228.jpg
# data\images\id_zizxk7ao1t.jpg
# data\images\id_g2qoimboyc.jpg
# data\images\id_nl3aeas2wu.jpg
# data\images\id_p6omtmwcl1.jpg
# data\images\id_j0s3jncce7.jpg
# data\images\id_b9qlq9zy3e.jpg
# data\images\id_jo8uyjrgbt.jpg
# data\images\id_geau0p533v.jpg
# data\images\id_tuiwsxil2e.jpg
# data\images\id_cj34acrxx6.jpg
# data\images\id_cc2lcr49xv.jpg
# data\images\id_15keeum3u3.jpg
# data\images\id_qkz8b1sany.jpg
# data\images\id_xculy3gzpk.jpg
# data\images\id_uajqyx7muw.jpg
# data\images\id_7awgmgcjl0.jpg
# data\images\id_fn9duuohc1.jpg
# data\images\id_hdpzuf5maf.jpg
# data\images\id_f1532fixpr.jpg
# data\images\id_rpm8vl68k1.jpg
# data\images\id_pms9qxpoz3.jpg
# data\images\id_cn2wq4vf4s.jpg
# data\images\id_08gqt771w1.jpg
# data\images\id_pn6iyrdqqz.jpg
# data\images\id_3l42ck1ho6.jpg
# data\images\id_os8jopl2gg.jpg
# data\images\id_qpb79mu7tz.jpg
# data\images\id_qx75hbrn2f.jpg
# data\images\id_ojyxvwz9ej.jpg
# data\images\id_fa626uztwq.jpg
# data\images\id_gsazi483u2.jpg
# data\images\id_2p2dyhdw1h.jpg
# data\images\id_kr733n1tsu.jpg
# data\images\id_331urb6uko.jpg
# data\images\id_5dkxygfay2.jpg
# data\images\id_w19x86t1oj.jpg
# data\images\id_7tgo99b7gy.jpg
# data\images\id_hoa430w9u9.jpg
# data\images\id_asx2u1dvli.jpg
# data\images\id_ml7s0vyb5x.jpg
# data\images\id_hth9rvjbef.jpg
# data\images\id_vyaa2w0dpf.jpg
# data\images\id_e9fd19ggmu.jpg
# data\images\id_p1z8i43g1e.jpg
# data\images\id_28rvbnyy8f.jpg
# data\images\id_m6dwuex9rp.jpg
# data\images\id_2oa39x5om5.jpg
# data\images\id_yvysltliu6.jpg
# data\images\id_j0zahs4ik5.jpg
# data\images\id_ezd6x40fd0.jpg
# data\images\id_mo2v2kgx60.jpg
# data\images\id_az75itcgjz.jpg
# data\images\id_ze8tixkhzb.jpg
# data\images\id_e1dww3um75.jpg
# data\images\id_yvysltliu6.jpg
# data\images\id_a10k5zohch.jpg
# data\images\id_li63u65zdf.jpg
# data\images\id_is6qvm3hoj.jpg
# data\images\id_k4ly4467l9.jpg
# data\images\id_tbop9cccoc.jpg
# data\images\id_q0kxllm8q2.jpg
# data\images\id_c9zfocph2k.jpg
# data\images\id_0ra59zawhn.jpg
# data\images\id_a1jdwsbpyl.jpg
# data\images\id_ng9b37pjh8.jpg
# data\images\id_tgpg2oujnz.jpg
# data\images\id_2fk6cyep6k.jpg
# data\images\id_q64taqr7xa.jpg
# data\images\id_um5sxszvdq.jpg
# data\images\id_r7rcvu1zc8.jpg
# data\images\id_5twlbmjcbu.jpg
# data\images\id_641yuyjn1f.jpg
# data\images\id_5gudsszz0t.jpg
# data\images\id_5q7uw7so7o.jpg
# data\images\id_uucqe1kzry.jpg
# data\images\id_r90wmxlo7g.jpg
# data\images\id_frahdlz5n3.jpg
# data\images\id_eerjo3sps4.jpg
# data\images\id_tbpcnvvgo4.jpg
# data\images\id_vmn1yepcxy.jpg
# data\images\id_womj1xex2p.jpg
# data\images\id_hoa430w9u9.jpg
# data\images\id_ehv8li5s95.jpg
# data\images\id_f1e3aetgv3.jpg
# data\images\id_44fqfdw5v9.jpg
# data\images\id_poz5lzruth.jpg
# data\images\id_331urb6uko.jpg
# data\images\id_c36hkm2atp.jpg
# data\images\id_4y1b6jhgue.jpg
# data\images\id_rnp8fcintk.jpg
# data\images\id_og5x0uny64.jpg
# data\images\id_kyre63f2tm.jpg
# data\images\id_nwy9oayw6h.jpg
# data\images\id_v60cs7d77g.jpg
# data\images\id_wft4oplzxm.jpg
# data\images\id_1xpbtfb4xh.jpg
# data\images\id_43cevf8y4e.jpg
# data\images\id_bw8mq2lrsq.jpg
# data\images\id_i20oi7qcal.jpg
# data\images\id_qk46xf80l5.jpg
# data\images\id_77yvo7djvx.jpg
# data\images\id_s15z5p4sev.jpg
# data\images\id_4vwgs6al82.jpg
# data\images\id_24ax5m76mp.jpg
# data\images\id_jnpgwdsny5.jpg
# data\images\id_n0dqkovtp3.jpg
# data\images\id_bw8mq2lrsq.jpg
# data\images\id_is6qvm3hoj.jpg
# data\images\id_nwy9oayw6h.jpg
# data\images\id_8jlhuhhu5y.jpg
# data\images\id_4y1b6jhgue.jpg
# data\images\id_c6hmbeixdl.jpg
# data\images\id_n43eeu01e8.jpg
# data\images\id_yevaz35ll1.jpg
# data\images\id_4ff79j4gv4.jpg
# data\images\id_0de37ox1bm.jpg
# data\images\id_suusi5hn1y.jpg
# data\images\id_kemmb57ure.jpg
# data\images\id_qkz8b1sany.jpg
# data\images\id_idjqlz4ppb.jpg
# data\images\id_rjjkcsmkbh.jpg
# data\images\id_tbop9cccoc.jpg
# data\images\id_q64taqr7xa.jpg
# data\images\id_xeuwa8b3u9.jpg
# data\images\id_a5nf4ezn3v.jpg
# data\images\id_fddvaawmcf.jpg
# data\images\id_zk5f24dvrh.jpg
# data\images\id_is6qvm3hoj.jpg
# data\images\id_6r4u8vcjay.jpg
# data\images\id_tu8mibp371.jpg
# data\images\id_wmni25iax5.jpg
# data\images\id_ktdlh7cwmo.jpg
# data\images\id_8rey0fnt6i.jpg
# data\images\id_vqxavxbgqv.jpg
# data\images\id_et5erpllpf.jpg
# data\images\id_9x09ltbdkc.jpg
# data\images\id_cilsouekou.jpg
# data\images\id_cq2c1jqghj.jpg
# data\images\id_jo8uyjrgbt.jpg
# data\images\id_b8gwvmjynv.jpg
# data\images\id_8rey0fnt6i.jpg
# data\images\id_yvysltliu6.jpg
# data\images\id_8aq7cnhtl5.jpg
# data\images\id_nl3aeas2wu.jpg
# data\images\id_a36aomg01d.jpg
# data\images\id_tkqnlwx1y5.jpg
# data\images\id_i0sssks1lo.jpg
# data\images\id_mn8un57jgm.jpg
# data\images\id_b9i2zz9yug.jpg
# data\images\id_87ddfyvrdq.jpg
# data\images\id_20lexlrojc.jpg
# data\images\id_h5ju5jauec.jpg
# data\images\id_io6mu601ef.jpg
# data\images\id_kfxb2211ni.jpg
# data\images\id_c6gycr0ll7.jpg
# data\images\id_5jnsug69k7.jpg
# data\images\id_zoa6mk680j.jpg
# data\images\id_j8foptaf6f.jpg
# data\images\id_9qtfjptkch.jpg
# data\images\id_0c5lr28fpt.jpg
# data\images\id_z9ajsvm7z8.jpg
# data\images\id_jd4i30cqy7.jpg
# data\images\id_ch6r0g46fr.jpg
# data\images\id_zgkogavjc0.jpg
# data\images\id_q7l2awwq7g.jpg
# data\images\id_jd4i30cqy7.jpg
# data\images\id_h8al1nu1ms.jpg
# data\images\id_k061rd9uty.jpg
# data\images\id_jnpgwdsny5.jpg
# data\images\id_yd3tmwvvgu.jpg
# data\images\id_dk4e23tnbl.jpg
# data\images\id_8oi9oz3jlb.jpg
# data\images\id_qg95y3rm5q.jpg
# data\images\id_2fk6cyep6k.jpg
# data\images\id_bktdwmg4lm.jpg
# data\images\id_yzhkb0zf37.jpg
# data\images\id_fqz06epe0k.jpg
# data\images\id_btfcsd8hls.jpg
# data\images\id_7wk6y42ce8.jpg
# data\images\id_87ddfyvrdq.jpg
# data\images\id_7chz2q4dsm.jpg
# data\images\id_3uhacauaez.jpg
# data\images\id_k9y7thvkcb.jpg
# data\images\id_i0sssks1lo.jpg
# data\images\id_vkasft3kl4.jpg
# data\images\id_8ixgyugm6f.jpg
# data\images\id_sp3aywnevu.jpg
# data\images\id_q2wywhkxho.jpg
# data\images\id_93qn6bexv7.jpg
# data\images\id_9f1y6j5b9d.jpg
# data\images\id_rpm8vl68k1.jpg
# data\images\id_nk6b8hdvu3.jpg
# data\images\id_h5p5jtx9x5.jpg
# data\images\id_a4dlrgudtn.jpg
# data\images\id_sho4od6kye.jpg
# data\images\id_nw02fw99a0.jpg
# data\images\id_ktkjovp8ey.jpg
# data\images\id_k061rd9uty.jpg
# data\images\id_ilmjjeqpcy.jpg
# data\images\id_epdgxdr9xf.jpg
# data\images\id_3vtq93cpm1.jpg
# data\images\id_epdgxdr9xf.jpg
# data\images\id_7g7lj99tg4.jpg
# data\images\id_99dqny1a0l.jpg
# data\images\id_tmtzoe9bns.jpg
# data\images\id_mr57qqhvl7.jpg
# data\images\id_ludahm1p2e.jpg
# data\images\id_nwy9oayw6h.jpg
# data\images\id_dywyswudfa.jpg
# data\images\id_ks29w27js0.jpg
# data\images\id_z92kgzdl9u.jpg
# data\images\id_f7dzlbfp75.jpg
# data\images\id_on8sxjlnsc.jpg
# data\images\id_ni84jbmadv.jpg
# data\images\id_jf6uwv1x6s.jpg
# data\images\id_nlhs0bubx8.jpg
# data\images\id_uvqwula1h9.jpg
# data\images\id_xj1a6r2me5.jpg
# data\images\id_ylrsd2a6k4.jpg
# data\images\id_q0kxllm8q2.jpg
# data\images\id_5qe8szb7zh.jpg
# data\images\id_j225bk8clg.jpg
# data\images\id_p1z8i43g1e.jpg
# data\images\id_kr733n1tsu.jpg
# data\images\id_6h82kx4fcs.jpg
# data\images\id_0abe9pv80b.jpg
# data\images\id_f8ankpuwfj.jpg
# data\images\id_ch6r0g46fr.jpg
# data\images\id_v1glu8ryq3.jpg
# data\images\id_9d04pt29ci.jpg
# data\images\id_njgy63grdy.jpg
# data\images\id_unbxbat1t9.jpg
# data\images\id_8og9rd87b0.jpg
# data\images\id_1i2c98t2s2.jpg
# data\images\id_e1z1cyw0i1.jpg
# data\images\id_htd8yeuu1d.jpg
# data\images\id_d1g42czqeh.jpg
# data\images\id_8l8zssuabc.jpg
# data\images\id_kmh7ea7qta.jpg
# data\images\id_ahl2a3kly0.jpg
# data\images\id_fz7geywf9w.jpg
# data\images\id_wtp7vfwf0j.jpg
# data\images\id_46m3wok9a6.jpg
# data\images\id_bbbzvnmoqd.jpg
# data\images\id_0fdars2kkw.jpg
# data\images\id_e4mdst4zi1.jpg
# data\images\id_ivl68a0hxd.jpg
# data\images\id_kkir4tuqai.jpg
# data\images\id_r7rcvu1zc8.jpg
# data\images\id_hudm26qzdw.jpg
# data\images\id_3jyozt96a3.jpg
# data\images\id_ks4su5m3hj.jpg
# data\images\id_gtyf1219br.jpg
# data\images\id_yxd1bn2bnt.jpg
# data\images\id_1qn4rhienv.jpg
# data\images\id_48b1s36zmc.jpg
# data\images\id_qx75hbrn2f.jpg
# data\images\id_23rsmol80e.jpg
# data\images\id_0pex8jec2z.jpg
# data\images\id_wczc5k3dwj.jpg
# data\images\id_48znynbs76.jpg
# data\images\id_wxaxv22nhy.jpg
# data\images\id_tm9d3cl87f.jpg
# data\images\id_9z6ajhl5wl.jpg
# data\images\id_nq17i56sa6.jpg
# data\images\id_tkqnlwx1y5.jpg
# data\images\id_zb39t8q1ks.jpg
# data\images\id_ui292hgdmi.jpg
# data\images\id_e23dyybn4a.jpg
# data\images\id_8rsxptmxkc.jpg
# data\images\id_i0sssks1lo.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_w01gu00ojz.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_ysi2242k6l.jpg
# data\images\id_6fbhkyv1rd.jpg
# data\images\id_px67dwlw7n.jpg
# data\images\id_pnave1opt9.jpg
# data\images\id_nrigd8iz8k.jpg
# data\images\id_yevaz35ll1.jpg
# data\images\id_ehv8li5s95.jpg
# data\images\id_ctkvvkc84k.jpg
# data\images\id_ndx918oj23.jpg
# data\images\id_nfscssxd2u.jpg
# data\images\id_8jgef5mjwc.jpg
# data\images\id_3r8qyxxxxc.jpg
# data\images\id_2wsz8etqq8.jpg
# data\images\id_ykdw2stt19.jpg
# data\images\id_trqgxmjszh.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_315zl7hmc7.jpg
# data\images\id_p4p38h0ecn.jpg
# data\images\id_15rb0dgq66.jpg
# data\images\id_wd51nh9072.jpg
# data\images\id_wq2owxeg15.jpg
# data\images\id_5gudsszz0t.jpg
# data\images\id_ib4bkb6uto.jpg
# data\images\id_mbvh28buo4.jpg
# data\images\id_au0abzw8wd.jpg
# data\images\id_3rrbg84f29.jpg
# data\images\id_4a8p6pjb7f.jpg
# data\images\id_4tp8jcxq21.jpg
# data\images\id_gtyf1219br.jpg
# data\images\id_ipmba1040m.jpg
# data\images\id_2oa39x5om5.jpg
# data\images\id_ggsuqofel4.jpg
# data\images\id_0raf30mfqj.jpg
# data\images\id_z92kgzdl9u.jpg
# data\images\id_ixxqgodncy.jpg
# data\images\id_1o2oc7fqs8.jpg
# data\images\id_stsa6kt4zg.jpg
# data\images\id_u7424e0jbz.jpg
# data\images\id_t04n6yjoc0.jpg
# data\images\id_8og9rd87b0.jpg
# data\images\id_onz4txmgh4.jpg
# data\images\id_e1z1cyw0i1.jpg
# data\images\id_7z4kmeq9c7.jpg
# data\images\id_a4dlrgudtn.jpg
# data\images\id_590z3x68ot.jpg
# data\images\id_vkasft3kl4.jpg
# data\images\id_b9i2zz9yug.jpg
# data\images\id_dmyxhehyfz.jpg
# data\images\id_jd4i30cqy7.jpg
# data\images\id_afv626iamx.jpg
# data\images\id_fmofpxvw0i.jpg
# data\images\id_4gtxlyjjqe.jpg
# data\images\id_b3dellefqq.jpg
# data\images\id_3vl2211vbz.jpg
# data\images\id_um5sxszvdq.jpg
# data\images\id_y9su4e1u73.jpg
# data\images\id_byo00s7ha5.jpg
# data\images\id_n5talfnmmk.jpg
# data\images\id_a1jdwsbpyl.jpg
# data\images\id_oq3gg3n3v0.jpg
# data\images\id_flts3nx55d.jpg
# data\images\id_ohdqwwlnpv.jpg
# data\images\id_jtghx9mo7e.jpg
# data\images\id_5mbjba0hyl.jpg
# data\images\id_io6mu601ef.jpg
# data\images\id_0c5lr28fpt.jpg
# data\images\id_k061rd9uty.jpg
# data\images\id_wumeg8bwk7.jpg
# data\images\id_ysi2242k6l.jpg
# data\images\id_4vwgs6al82.jpg
# data\images\id_bf5z9bx9xf.jpg
# data\images\id_7chz2q4dsm.jpg
# data\images\id_sn780dq4g9.jpg
# data\images\id_ac7q1ehp23.jpg
# data\images\id_wq2owxeg15.jpg
# data\images\id_bylmx08z0u.jpg
# data\images\id_l90j3qhlpz.jpg
# data\images\id_zdg96srigj.jpg
# data\images\id_cgccsf7xyt.jpg
# data\images\id_3rrbg84f29.jpg
# data\images\id_5e3mzdro2p.jpg
# data\images\id_j80khun6jy.jpg
# data\images\id_0fdars2kkw.jpg
# data\images\id_9ctex4nrc1.jpg
# data\images\id_331urb6uko.jpg
# data\images\id_2phbgf1x5m.jpg
# data\images\id_31mr88emf3.jpg
# data\images\id_p24s9ciioq.jpg
# data\images\id_u8gkyu4gc4.jpg
# data\images\id_4cgsb6hlt0.jpg
# data\images\id_s2xx0ywozw.jpg
# data\images\id_lvd73frjuz.jpg
# data\images\id_is6qvm3hoj.jpg
# data\images\id_re74wr6nyy.jpg
# data\images\id_qg95y3rm5q.jpg
# data\images\id_20lexlrojc.jpg
# data\images\id_ca3q45a1rs.jpg
# data\images\id_6r4u8vcjay.jpg
# data\images\id_5r1k5g43dg.jpg
# data\images\id_04gtt1v9w0.jpg
# data\images\id_mzq1jmom69.jpg
# data\images\id_wczc5k3dwj.jpg
# data\images\id_ie9392cr9c.jpg
# data\images\id_v7f4pdivy1.jpg
# data\images\id_0nm5i3vtg9.jpg
# data\images\id_zk5f24dvrh.jpg
# data\images\id_piks21idhv.jpg
# data\images\id_p1z8i43g1e.jpg
# data\images\id_a4dlrgudtn.jpg
# data\images\id_uhbqlk1fm0.jpg
# data\images\id_06xcou9044.jpg
# data\images\id_bvht7rqdqs.jpg
# data\images\id_yzhkb0zf37.jpg
# data\images\id_j0zahs4ik5.jpg
# data\images\id_xa4qfbdy8x.jpg
# data\images\id_gyoporclq9.jpg
# data\images\id_u2ycfaq5e0.jpg
# data\images\id_ef4lnbhyxw.jpg
# data\images\id_93qn6bexv7.jpg
# data\images\id_38aav4v9kr.jpg
# data\images\id_wy8p0eu51i.jpg
# data\images\id_xculy3gzpk.jpg
# data\images\id_um5sxszvdq.jpg
# data\images\id_ng9b37pjh8.jpg
# data\images\id_i5tsin8ztt.jpg
# data\images\id_jl93f5rtzc.jpg
# data\images\id_48znynbs76.jpg
# data\images\id_7wk6y42ce8.jpg
# data\images\id_mkvxxar9qw.jpg
# data\images\id_35bu6qgofu.jpg
# data\images\id_qkz8b1sany.jpg
# data\images\id_ezd6x40fd0.jpg
# data\images\id_pe5g1sn04p.jpg
# data\images\id_q4pmxshnf8.jpg
# data\images\id_96z5kq4fxn.jpg
# data\images\id_ajetqytbnc.jpg
# data\images\id_3vtq93cpm1.jpg
# data\images\id_mo2v2kgx60.jpg
# data\images\id_ks4su5m3hj.jpg
# data\images\id_iisyobbs2a.jpg
# data\images\id_4vy2wvrrkd.jpg
# data\images\id_e23dyybn4a.jpg
# data\images\id_p6lql58dil.jpg
# data\images\id_sp3aywnevu.jpg
# data\images\id_lvd73frjuz.jpg
# data\images\id_vkasft3kl4.jpg
# data\images\id_v51xobxvyk.jpg
# data\images\id_mgtz4etyx1.jpg
# data\images\id_ml7s0vyb5x.jpg
# data\images\id_zw3ez6sob0.jpg
# data\images\id_bj4v8tg4n3.jpg
# data\images\id_5hw93ewqy9.jpg
# data\images\id_5bbz3srksa.jpg
# data\images\id_tbe6fmgu8x.jpg
# data\images\id_uahbj2v0w9.jpg
# data\images\id_xr7x8vmwrm.jpg
# data\images\id_pn6iyrdqqz.jpg
# data\images\id_piks21idhv.jpg
# data\images\id_a10k5zohch.jpg
# data\images\id_tnk9ptt8lu.jpg
# data\images\id_u68vnc3ig8.jpg
# data\images\id_15k6d9z1gu.jpg
# data\images\id_4zywetm95o.jpg
# data\images\id_obvyvrbfoa.jpg
# data\images\id_d723oa3cdr.jpg
# data\images\id_bvht7rqdqs.jpg
# data\images\id_gsazi483u2.jpg
# data\images\id_nl3aeas2wu.jpg
# data\images\id_zk5f24dvrh.jpg
# data\images\id_51n7h0tlm2.jpg
# data\images\id_8ken1mdqby.jpg
# data\images\id_w19x86t1oj.jpg
# data\images\id_qjae1syumg.jpg
# data\images\id_1fmmo9lp14.jpg
# data\images\id_3b3ueux5jl.jpg
# data\images\id_7288xs7ui3.jpg
# data\images\id_u7424e0jbz.jpg
# data\images\id_wk8p3mqvox.jpg
# data\images\id_20lexlrojc.jpg
# data\images\id_rjjkcsmkbh.jpg
# data\images\id_ns0ww9t3ju.jpg
# data\images\id_ib4bkb6uto.jpg
# data\images\id_no1g953uzv.jpg
# data\images\id_g9j9rxm05s.jpg
# data\images\id_ktkjovp8ey.jpg
# ...
# data\images\id_ptywmrfb4s.jpg
# data\images\id_y4hd9yvh59.jpg
# data\images\id_ugc3d0uqrm.jpg
# data\images\id_x8w2chd68q.jpg
# data\images\id_apji4r6dlw.jpg
# data\images\id_a3fboyv5nz.jpg
# data\images\id_7ugqazdluw.jpg
# data\images\id_smmi9b8nzk.jpg
# data\images\id_hr10y564wc.jpg
# data\images\id_8q5u21g42q.jpg
# data\images\id_n70defln6p.jpg
# data\images\id_uegaayinmp.jpg
# data\images\id_7zvlqlp8hc.jpg
# data\images\id_7ugqazdluw.jpg
# data\images\id_sqnutj2cxt.jpg
# data\images\id_h96zith5oz.jpg
# data\images\id_eb4ghgzugp.jpg
# data\images\id_rty8dzjldp.jpg
# data\images\id_9fyjq1ibpx.jpg
# data\images\id_f3orjo1cxc.jpg
# data\images\id_z7s5bijjye.jpg
# data\images\id_1ek659ass2.jpg
# data\images\id_du9knnffo5.jpg
# data\images\id_ldsohwqw5s.jpg
# data\images\id_lg934gctjs.jpg
# data\images\id_61axoyt1e6.jpg
# data\images\id_abm8rsfkq8.jpg
# data\images\id_2jtdlvl3lp.jpg
# data\images\id_9fyjq1ibpx.jpg
# data\images\id_pmq1hu1e71.jpg
# data\images\id_1d572clvxz.jpg
# data\images\id_qicgns95fp.jpg
# data\images\id_mlpsjyacxs.jpg
# data\images\id_18dksu2pcw.jpg
# data\images\id_6c66f8rw3u.jpg
# data\images\id_ngdidsmt6o.jpg
# data\images\id_31b9tof1dw.jpg
# data\images\id_vttvw22xt6.jpg
# data\images\id_drdob883op.jpg
# data\images\id_i4d0ulpq39.jpg
# data\images\id_trld6lawky.jpg
# data\images\id_wv8ze1pfbz.jpg
# data\images\id_s3k19v7ci3.jpg
# data\images\id_6crwq6ntmj.jpg
# data\images\id_d9km9wq3gf.jpg
# data\images\id_jsfiseoilv.jpg
# data\images\id_ue5wezctio.jpg
# data\images\id_7ugqazdluw.jpg
# data\images\id_rgyp8k6n27.jpg
# data\images\id_ujfwsahx99.jpg
# data\images\id_6vkj6zvsx2.jpg
# data\images\id_96yqsw3jpj.jpg
# data\images\id_cv1oiyd7a2.jpg
# data\images\id_nbs2c32913.jpg
# data\images\id_yrtdn6miil.jpg
# data\images\id_fwa2pa1goh.jpg
# data\images\id_okva4xz4nj.jpg
# data\images\id_0psx59eg7k.jpg
# data\images\id_8gv8ssaopt.jpg
# data\images\id_mjvd69lt7m.jpg
# data\images\id_5b0jo1djb2.jpg
# data\images\id_0psx59eg7k.jpg
# data\images\id_mfja8rjjyc.jpg
# data\images\id_mjvd69lt7m.jpg
# data\images\id_dxlkcvvfr0.jpg
# data\images\id_xi59tlcn6o.jpg
# data\images\id_f6eepaj5h3.jpg
# data\images\id_z7s5bijjye.jpg
# data\images\id_6x0d145kam.jpg
# data\images\id_d9km9wq3gf.jpg
# data\images\id_7ggrhk95br.jpg
# data\images\id_mfja8rjjyc.jpg
# data\images\id_x60tvano76.jpg
# data\images\id_1la6dmk7pp.jpg
# data\images\id_zi10qc2dd6.jpg
# data\images\id_hczakz2ht6.jpg
# data\images\id_8wlzhslrkm.jpg
# data\images\id_1hbw0l10vq.jpg
# data\images\id_uqlw7y0nad.jpg
# data\images\id_5mbe2nhipw.jpg
# data\images\id_nbs2c32913.jpg
# data\images\id_8wlzhslrkm.jpg
# data\images\id_y0jwpqzjfj.jpg
# data\images\id_xamxreu2mu.jpg
# data\images\id_wv8ze1pfbz.jpg
# data\images\id_fyi5c2t3zz.jpg
# data\images\id_6crwq6ntmj.jpg
# data\images\id_yzkn4hlwbk.jpg
# data\images\id_4x6xe60cb3.jpg
# data\images\id_mnm2l0p6hc.jpg
# data\images\id_c85ykg3uy2.jpg
# data\images\id_2h7p6t9oua.jpg
# data\images\id_isi5v1dbk9.jpg
# data\images\id_4a42vnhjjw.jpg
# data\images\id_14p9n4bif1.jpg
# data\images\id_69tmhfv0lu.jpg
# data\images\id_nskynnza0w.jpg
# data\images\id_0jxqq647bu.jpg
# data\images\id_gdm8100m5w.jpg
# data\images\id_okva4xz4nj.jpg
# data\images\id_69tmhfv0lu.jpg
# data\images\id_mlpsjyacxs.jpg
# data\images\id_3jrfzzpntr.jpg
# data\images\id_cqv7kuw7nl.jpg
# data\images\id_h8qqp0ylyo.jpg
# data\images\id_2h7p6t9oua.jpg
# data\images\id_du9knnffo5.jpg
# data\images\id_1760ihasgs.jpg
# data\images\id_69tmhfv0lu.jpg
# data\images\id_8wlzhslrkm.jpg
# data\images\id_14p9n4bif1.jpg
# data\images\id_6vkj6zvsx2.jpg
# data\images\id_vy2vkz5r7x.jpg
# data\images\id_eu2cd85l06.jpg
# data\images\id_t0in5kp2t2.jpg
# data\images\id_j6dps1u714.jpg
# data\images\id_q8g5ptlpha.jpg
# data\images\id_gzxlbrjcqz.jpg
# data\images\id_310rkvg7k4.jpg
# data\images\id_10bnf5rikw.jpg
# data\images\id_fwilzwxdl7.jpg
# data\images\id_okva4xz4nj.jpg
# data\images\id_rmwz6ce1dd.jpg
# data\images\id_4urj0kx8zk.jpg
# data\images\id_anwoop5gmd.jpg
# data\images\id_wyvqbie72r.jpg
# data\images\id_54hk016ddp.jpg
# data\images\id_7fd9tfijwa.jpg
# data\images\id_zke3rs4zch.jpg
# data\images\id_pdx2pcis09.jpg
# data\images\id_r4f1nwo0bw.jpg
# data\images\id_6mjcdr5wap.jpg
# data\images\id_6vkj6zvsx2.jpg
# data\images\id_rgyp8k6n27.jpg
# data\images\id_7fd9tfijwa.jpg
# data\images\id_5283833d2l.jpg
# data\images\id_5283833d2l.jpg
# data\images\id_jqpx1ud3i8.jpg
# data\images\id_6crwq6ntmj.jpg
# data\images\id_otmg6cg1qw.jpg
# data\images\id_ugc3d0uqrm.jpg
# data\images\id_njl8apjhd0.jpg
# data\images\id_69tmhfv0lu.jpg
# data\images\id_ohpxl9iya8.jpg
# data\images\id_lg934gctjs.jpg
# data\images\id_s91hx9uyin.jpg
# data\images\id_m9j0bdf838.jpg
# data\images\id_jxms9neg6t.jpg
# data\images\id_db7urn6j1g.jpg
# data\images\id_padsu6hm9j.jpg
# data\images\id_ia33y02kee.jpg
# data\images\id_sk5lr1glyx.jpg
# data\images\id_9brjtu88if.jpg
# data\images\id_dybaweybco.jpg
# data\images\id_glyh3dol96.jpg
# data\images\id_qqrsca42ls.jpg
# data\images\id_1gs2mk1ts7.jpg
# data\images\id_4hzkikux2p.jpg
# data\images\id_2htv5u7hgi.jpg
# data\images\id_qqrsca42ls.jpg
# data\images\id_t0in5kp2t2.jpg
# data\images\id_e1ivdpme15.jpg
# data\images\id_r83lt9zx3i.jpg
# data\images\id_2vypqq561o.jpg
# data\images\id_3wnymfzd89.jpg
# data\images\id_8909aolikp.jpg
# data\images\id_d7y7ez7cab.jpg
# data\images\id_cv1oiyd7a2.jpg
# data\images\id_9t9so3atr9.jpg
# data\images\id_rgyp8k6n27.jpg
# data\images\id_qqrsca42ls.jpg
# data\images\id_rgyp8k6n27.jpg
# data\images\id_f91py41r08.jpg
# data\images\id_0e1cx570oo.jpg
# data\images\id_pz9z939k3e.jpg
# data\images\id_l6grvsyujs.jpg
# data\images\id_dbq52ropeq.jpg
# data\images\id_rssaiirkbk.jpg
# data\images\id_1gs2mk1ts7.jpg
# data\images\id_k1opxd8t8q.jpg
# data\images\id_18dksu2pcw.jpg
# data\images\id_axrk9aq376.jpg
# data\images\id_96yqsw3jpj.jpg
# data\images\id_1la6dmk7pp.jpg
# data\images\id_y4net0xm8f.jpg
# data\images\id_eu2cd85l06.jpg
# data\images\id_apmwvq5z0g.jpg
# data\images\id_ugc3d0uqrm.jpg
# data\images\id_2d9g4htl0c.jpg
# data\images\id_itlhgpe0hv.jpg
# data\images\id_cqv7kuw7nl.jpg
# data\images\id_nx12u001w3.jpg
# data\images\id_mjvd69lt7m.jpg
# data\images\id_9brjtu88if.jpg
# data\images\id_hr10y564wc.jpg
# data\images\id_l59ye829l2.jpg
# data\images\id_gf10i90gho.jpg
# data\images\id_bw1qg3osng.jpg
# data\images\id_xamxreu2mu.jpg
# data\images\id_677y2cx30r.jpg
# data\images\id_otmg6cg1qw.jpg
# data\images\id_fo5klf8zjn.jpg
# data\images\id_db7urn6j1g.jpg
# data\images\id_mlpsjyacxs.jpg
# data\images\id_5t3iccynjw.jpg
# data\images\id_1ek659ass2.jpg
# data\images\id_3uvuspqr6q.jpg
# data\images\id_i4d0ulpq39.jpg
# data\images\id_vttvw22xt6.jpg
# data\images\id_5mbe2nhipw.jpg
# data\images\id_psyadz27fb.jpg
# data\images\id_s3k19v7ci3.jpg
# data\images\id_u8aecxtond.jpg
# data\images\id_jxms9neg6t.jpg
# data\images\id_9brjtu88if.jpg
# data\images\id_vttvw22xt6.jpg
# data\images\id_padsu6hm9j.jpg
# data\images\id_6xrrxr01u8.jpg
# data\images\id_xi59tlcn6o.jpg
# data\images\id_wv8ze1pfbz.jpg
# data\images\id_3xakbk4xct.jpg
# data\images\id_0e1cx570oo.jpg
# data\images\id_gzxlbrjcqz.jpg
# data\images\id_ou8nzuaktb.jpg
# data\images\id_kj9vtngvvt.jpg
# data\images\id_hxi5z1l5e7.jpg
# data\images\id_wbw8heo1g4.jpg
# data\images\id_1hbw0l10vq.jpg
# data\images\id_hczakz2ht6.jpg
# data\images\id_1ek659ass2.jpg
# data\images\id_td90d9r5sb.jpg
# data\images\id_3baftl81sb.jpg
# data\images\id_kj9vtngvvt.jpg
# data\images\id_sqnutj2cxt.jpg
# data\images\id_47owtyygrt.jpg
# data\images\id_fvpi1edl84.jpg
# data\images\id_dbq52ropeq.jpg
# data\images\id_zgkvnvxevi.jpg
# data\images\id_3vpyguxleh.jpg
# data\images\id_kj9vtngvvt.jpg
# data\images\id_ytq3slqkjm.jpg
# data\images\id_2de8i9fwtz.jpg
# data\images\id_q4gmq63cwr.jpg
# data\images\id_xc1iljwdc1.jpg
# data\images\id_3mdf5uv24g.jpg
# data\images\id_3jrfzzpntr.jpg
# data\images\id_cistrck71b.jpg
# data\images\id_pq06urws67.jpg
# data\images\id_ct9dymciri.jpg
# data\images\id_lwlxshxbpn.jpg
# data\images\id_c5cazqm2g4.jpg
# data\images\id_5htn65347z.jpg
# data\images\id_ntnj17v7b2.jpg
# data\images\id_gzxlbrjcqz.jpg
# data\images\id_wywjqv3drx.jpg
# data\images\id_9fyjq1ibpx.jpg
# data\images\id_rtsfp3txbj.jpg
# data\images\id_fjetcvnlj7.jpg
# data\images\id_nskynnza0w.jpg
# data\images\id_5zmwwyihmx.jpg
# data\images\id_abm8rsfkq8.jpg
# data\images\id_bvqgjt8ssi.jpg
# data\images\id_fwilzwxdl7.jpg
# data\images\id_kj9vtngvvt.jpg
# data\images\id_of4eykgxt5.jpg
# data\images\id_bvmglcm4cb.jpg
# data\images\id_2xqmc5dr2d.jpg
# data\images\id_6c66f8rw3u.jpg
# data\images\id_atyaxiymp6.jpg
# data\images\id_488ayirol0.jpg
# data\images\id_c3knhu1grr.jpg
# data\images\id_0psx59eg7k.jpg
# data\images\id_8pvg950tez.jpg
# data\images\id_ct9dymciri.jpg
# data\images\id_gjkbres5x6.jpg
# data\images\id_qe01v7wsc5.jpg
# data\images\id_y0jwpqzjfj.jpg
# data\images\id_3t3uk40b2i.jpg
# data\images\id_d5dj2koz0y.jpg
# data\images\id_njl8apjhd0.jpg
# data\images\id_apji4r6dlw.jpg
# data\images\id_4pn3ye9qej.jpg
# data\images\id_cv1oiyd7a2.jpg
# data\images\id_488ayirol0.jpg
# data\images\id_r9abxdhok9.jpg
# data\images\id_u7grd5cjlv.jpg
# data\images\id_d7y7ez7cab.jpg
# data\images\id_u0ixesq8l0.jpg
# data\images\id_bu04j7jxbr.jpg
# data\images\id_2jtdlvl3lp.jpg
# data\images\id_3br3wrtadm.jpg
# data\images\id_vdchlkv6hv.jpg
# data\images\id_7ugqazdluw.jpg
# data\images\id_44qx8w0k1s.jpg
# data\images\id_ybz383ke13.jpg
# data\images\id_mffzgxolw5.jpg
# data\images\id_ct9dymciri.jpg
# data\images\id_8kgrljo1dk.jpg
# data\images\id_axrk9aq376.jpg
# data\images\id_ilz0fjuyqz.jpg
# data\images\id_7fd9tfijwa.jpg
# data\images\id_6o8cxplppe.jpg
# data\images\id_crv6y63llw.jpg
# data\images\id_qmjzvjtx05.jpg
# data\images\id_kthpieuqnz.jpg
# data\images\id_mfja8rjjyc.jpg
# data\images\id_j6dps1u714.jpg
# data\images\id_dnzk3am2hb.jpg
# data\images\id_fwilzwxdl7.jpg
# data\images\id_1ek659ass2.jpg
# data\images\id_2h7p6t9oua.jpg
# data\images\id_mbeflw8vpy.jpg
# data\images\id_mfja8rjjyc.jpg
# data\images\id_a6cl90trri.jpg
# data\images\id_njl8apjhd0.jpg
# data\images\id_xr2wompa5z.jpg
# data\images\id_dnm28npu2a.jpg
# data\images\id_sk5lr1glyx.jpg
# data\images\id_qp6w3lkwpw.jpg
# data\images\id_bu04j7jxbr.jpg
# data\images\id_yzkn4hlwbk.jpg
# data\images\id_1ek659ass2.jpg
# data\images\id_okva4xz4nj.jpg
# data\images\id_3mawpvd064.jpg
# data\images\id_89gbwthdlx.jpg
# data\images\id_cv1oiyd7a2.jpg
# data\images\id_gzxlbrjcqz.jpg
# data\images\id_g71y6lc94l.jpg
# data\images\id_18dksu2pcw.jpg
# data\images\id_qqrsca42ls.jpg
# data\images\id_sk5lr1glyx.jpg
# data\images\id_83ft3yit5m.jpg
# data\images\id_mereo6283h.jpg
# data\images\id_ldsohwqw5s.jpg
# data\images\id_y6uqii4ury.jpg
# data\images\id_kj9vtngvvt.jpg
# data\images\id_6bs4zqzvfr.jpg
# data\images\id_0n11k4le6s.jpg
# data\images\id_sk5lr1glyx.jpg
# data\images\id_s91hx9uyin.jpg
# data\images\id_q944tcfd13.jpg
# data\images\id_jxms9neg6t.jpg
# data\images\id_eb4ghgzugp.jpg
# data\images\id_ohpxl9iya8.jpg
# data\images\id_d9km9wq3gf.jpg
# data\images\id_u7grd5cjlv.jpg
# data\images\id_3g5q7v1owr.jpg
# data\images\id_q18tfhfneh.jpg
# data\images\id_pq06urws67.jpg
# data\images\id_sgi34ryz73.jpg
# data\images\id_f7v2la0a2a.jpg
# data\images\id_cv1oiyd7a2.jpg
# data\images\id_88wih42jlj.jpg
# data\images\id_8q5u21g42q.jpg
# data\images\id_av2otqquhi.jpg
# data\images\id_da9jjezfca.jpg
# data\images\id_wg1m61aklu.jpg
# data\images\id_j6dps1u714.jpg
# data\images\id_0e1cx570oo.jpg
# data\images\id_s91hx9uyin.jpg
# data\images\id_eu2cd85l06.jpg
# data\images\id_vy2vkz5r7x.jpg
# data\images\id_xbb8d94g1c.jpg
# data\images\id_erwxtzu064.jpg
# data\images\id_hczakz2ht6.jpg
# data\images\id_2htv5u7hgi.jpg
# data\images\id_ef0jw5a0zi.jpg
# data\images\id_1ek659ass2.jpg
# data\images\id_58ee05nnpt.jpg
# data\images\id_s3k19v7ci3.jpg
# data\images\id_gzxlbrjcqz.jpg
# data\images\id_s8265awk6h.jpg
# data\images\id_rxur32j6k2.jpg
# data\images\id_2htv5u7hgi.jpg
# data\images\id_y6uqii4ury.jpg
# data\images\id_rqgxzhzly1.jpg
# data\images\id_5b0jo1djb2.jpg
# data\images\id_okva4xz4nj.jpg
# data\images\id_vtqdhvqnrx.jpg
# data\images\id_oavpuolgcm.jpg
# data\images\id_6ew1o5b678.jpg
# data\images\id_okva4xz4nj.jpg
# data\images\id_1ek659ass2.jpg
# data\images\id_d5dj2koz0y.jpg
# data\images\id_n9xdokysvj.jpg
# data\images\id_apmwvq5z0g.jpg
# data\images\id_da9jjezfca.jpg
# data\images\id_db7urn6j1g.jpg
# data\images\id_jkfuq49s29.jpg
# data\images\id_89gbwthdlx.jpg
# data\images\id_2h7p6t9oua.jpg
# data\images\id_2htv5u7hgi.jpg
# data\images\id_a5vcx22lnz.jpg
# data\images\id_tzxt79u3ec.jpg
# data\images\id_5bvosl2pau.jpg
# data\images\id_ukfbjar9g0.jpg
# data\images\id_6crwq6ntmj.jpg
# data\images\id_2d9g4htl0c.jpg
# data\images\id_55a6sf8hbe.jpg
# data\images\id_v00bbsdplf.jpg
# data\images\id_q18tfhfneh.jpg
# data\images\id_qwlbeo6f16.jpg
# data\images\id_ty165y6vot.jpg
# data\images\id_6bs4zqzvfr.jpg
# data\images\id_2de8i9fwtz.jpg
# data\images\id_7fc9zyfy0e.jpg
# data\images\id_oc5se3b1wo.jpg
# data\images\id_1gs2mk1ts7.jpg
# data\images\id_bu04j7jxbr.jpg
# data\images\id_lgipcm9ma1.jpg
# data\images\id_r83lt9zx3i.jpg
# data\images\id_0jxqq647bu.jpg
# data\images\id_5gi4m9bua5.jpg
# data\images\id_0psx59eg7k.jpg
# data\images\id_eb4ghgzugp.jpg
# data\images\id_mnm2l0p6hc.jpg
# data\images\id_lmx17pougj.jpg
# data\images\id_ejyw8kqbhh.jpg
# data\images\id_69tmhfv0lu.jpg
# data\images\id_jkfuq49s29.jpg
# data\images\id_v15t6lc890.jpg
# data\images\id_1iia796cjq.jpg
# data\images\id_6x0d145kam.jpg
# data\images\id_fj0nb1076n.jpg
# data\images\id_i8qcpi8ey9.jpg
# data\images\id_z7s5bijjye.jpg
# data\images\id_6g52lmvz2y.jpg
# data\images\id_bu04j7jxbr.jpg
# data\images\id_s91hx9uyin.jpg
# data\images\id_i8qcpi8ey9.jpg
# data\images\id_9brjtu88if.jpg
# data\images\id_wbf7r0vube.jpg
# data\images\id_ugc3d0uqrm.jpg
# data\images\id_atyaxiymp6.jpg
# data\images\id_bu04j7jxbr.jpg
# data\images\id_3xakbk4xct.jpg
# data\images\id_9brjtu88if.jpg
# data\images\id_3mawpvd064.jpg
# data\images\id_d9km9wq3gf.jpg
# data\images\id_m2sb3vo43l.jpg
# data\images\id_1d572clvxz.jpg
# data\images\id_atyaxiymp6.jpg
# data\images\id_7dx8g4mpkk.jpg
# data\images\id_y0jwpqzjfj.jpg
# data\images\id_s8cpxmp35g.jpg
# data\images\id_b7oywplcts.jpg
# data\images\id_fo5klf8zjn.jpg
# data\images\id_9fyjq1ibpx.jpg
# data\images\id_1la6dmk7pp.jpg
# data\images\id_ugc3d0uqrm.jpg
# data\images\id_hczakz2ht6.jpg
# data\images\id_ilz0fjuyqz.jpg
# data\images\id_ldsohwqw5s.jpg
# data\images\id_8wlzhslrkm.jpg
# data\images\id_1la6dmk7pp.jpg
# data\images\id_1kdccg2hed.jpg
# data\images\id_drdob883op.jpg
# data\images\id_e1ivdpme15.jpg
# data\images\id_s91hx9uyin.jpg
# data\images\id_1hbw0l10vq.jpg
# data\images\id_xi59tlcn6o.jpg
# data\images\id_54hk016ddp.jpg
# data\images\id_6csaqnzto8.jpg
# data\images\id_pg39cn27xo.jpg
# data\images\id_sbru10y5pc.jpg
# data\images\id_ofrena6jju.jpg
# data\images\id_9fyjq1ibpx.jpg
# data\images\id_0n11k4le6s.jpg
# data\images\id_dj7q6qdgvk.jpg
# data\images\id_oeg81pq0yc.jpg
# data\images\id_ejyw8kqbhh.jpg
# data\images\id_gzxlbrjcqz.jpg
# data\images\id_s3k19v7ci3.jpg
# data\images\id_6o8cxplppe.jpg
# data\images\id_00sirs797x.jpg
# data\images\id_3t3uk40b2i.jpg
# data\images\id_8kgrljo1dk.jpg
# data\images\id_ghp8x3ioh0.jpg
# data\images\id_y0jwpqzjfj.jpg
# data\images\id_1gs2mk1ts7.jpg
# data\images\id_488ayirol0.jpg
# data\images\id_cz18328ivv.jpg
# data\images\id_69tmhfv0lu.jpg
# data\images\id_uqlw7y0nad.jpg
# data\images\id_bu04j7jxbr.jpg
# data\images\id_rbhimh3i2j.jpg
# data\images\id_8gv8ssaopt.jpg
# data\images\id_c9jz5nh48h.jpg
# data\images\id_gmjzttp90b.jpg
# data\images\id_h96zith5oz.jpg
# data\images\id_jsfiseoilv.jpg
# data\images\id_ivac7m1wwl.jpg
# data\images\id_s91hx9uyin.jpg
# data\images\id_ytq3slqkjm.jpg
# data\images\id_j6dps1u714.jpg
# data\images\id_7fd9tfijwa.jpg
# data\images\id_2htv5u7hgi.jpg
# data\images\id_ct9dymciri.jpg
# data\images\id_488ayirol0.jpg
# data\images\id_49n2r2g61a.jpg
# data\images\id_c5vt1lql3c.jpg
# data\images\id_g7s14wkt7k.jpg
# data\images\id_g7s14wkt7k.jpg
# data\images\id_s3k19v7ci3.jpg
# data\images\id_6c66f8rw3u.jpg
# data\images\id_lqh7ff19v7.jpg
# data\images\id_7gvvrdz0tl.jpg
# data\images\id_wga5l8jeh5.jpg
# data\images\id_fwa2pa1goh.jpg
# data\images\id_5bvosl2pau.jpg
# data\images\id_a1ladv8a2p.jpg
# data\images\id_pz9z939k3e.jpg
# data\images\id_gf10i90gho.jpg
# data\images\id_d9km9wq3gf.jpg
# data\images\id_ytq3slqkjm.jpg
# data\images\id_vy2vkz5r7x.jpg
# data\images\id_d9km9wq3gf.jpg
# data\images\id_7wc3vtwhf2.jpg
# data\images\id_83ft3yit5m.jpg
# data\images\id_bu04j7jxbr.jpg
# data\images\id_x60tvano76.jpg
# data\images\id_5bvosl2pau.jpg
# data\images\id_hxi5z1l5e7.jpg
# data\images\id_db7urn6j1g.jpg
# data\images\id_3vpyguxleh.jpg
# data\images\id_ue5wezctio.jpg
# data\images\id_dl2kaag27a.jpg
# data\images\id_qqrsca42ls.jpg
# data\images\id_db7urn6j1g.jpg
# data\images\id_hczakz2ht6.jpg
# data\images\id_vttvw22xt6.jpg
# data\images\id_61axoyt1e6.jpg
# data\images\id_r2x9t2l5cd.jpg

# %%
# Train images dir
TRAIN_IMAGES_DIR
# Out:
# WindowsPath('datasets/dataset/images/train')

# %%
# Create a data.yaml file required by yolo
class_names = train['class'].unique().tolist()
num_classes = len(class_names)

data_yaml = {
    'train': '/' + str(TRAIN_IMAGES_DIR),
    'val': '/' + str(VAL_IMAGES_DIR),
    'test': '/' + str(TEST_IMAGES_DIR),
    'nc': num_classes,
    'names': class_names
}

yaml_path = 'data.yaml'
with open(yaml_path, 'w') as file:
    yaml.dump(data_yaml, file, default_flow_style=False)

# Preview data yaml file
data_yaml
# Out:
# {'train': '/datasets\\dataset\\images\\train',
#  'val': '/datasets\\dataset\\images\\val',
#  'test': '/datasets\\dataset\\images\\test',
#  'nc': 2,
#  'names': ['Trophozoite', 'WBC']}

# %%
# Plot some images and their bboxes to ensure the conversion was done correctly
def load_annotations(label_path):
    with open(label_path, 'r') as f:
        lines = f.readlines()
    boxes = []
    for line in lines:
        class_id, x_center, y_center, width, height = map(float, line.strip().split())
        boxes.append((class_id, x_center, y_center, width, height))
    return boxes

# Function to plot an image with its bounding boxes
def plot_image_with_boxes(image_path, boxes):
    # Load the image
    image = cv2.imread(str(image_path))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Get image dimensions
    h, w, _ = image.shape

    # Plot the image
    plt.figure(figsize=(10, 10))
    plt.imshow(image)

    # Plot each bounding box
    for box in boxes:
        class_id, x_center, y_center, width, height = box
        # Convert YOLO format to corner coordinates
        xmin = int((x_center - width / 2) * w)
        ymin = int((y_center - height / 2) * h)
        xmax = int((x_center + width / 2) * w)
        ymax = int((y_center + height / 2) * h)

        # Draw the bounding box
        plt.gca().add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                          edgecolor='red', facecolor='none', linewidth=2))
        plt.text(xmin, ymin - 10, f'Class {int(class_id)}', color='red', fontsize=12, weight='bold')

    plt.axis('off')
    plt.show()

# Directories for images and labels
IMAGE_DIR = TRAIN_IMAGES_DIR
LABEL_DIR = TRAIN_LABELS_DIR

# Plot a few images with their annotations
for image_name in os.listdir(IMAGE_DIR)[:3]:
    image_path = IMAGE_DIR / image_name
    label_path = LABEL_DIR / (image_name.replace('.jpg', '.txt').replace('.png', '.txt'))

    if label_path.exists():
        boxes = load_annotations(label_path)
        print(f"Plotting {image_name} with {len(boxes)} bounding boxes.")
        plot_image_with_boxes(image_path, boxes)
    else:
        print(f"No annotations found for {image_name}.")
# Out:
# Plotting id_0051lznyrt.jpg with 4 bounding boxes.
# Plotting id_021o79u9zs.jpg with 16 bounding boxes.
# Plotting id_02q5ah1zvq.jpg with 5 bounding boxes.

# %%
# install -u ultalytics
# !pip install -U ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (8.3.13)
# Collecting ultralytics
#   Downloading ultralytics-8.3.20-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (4.10.0)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (0.19.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from ultralytics) (2.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.1)
# Requirement already satisfied: jinja2 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: setuptools in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from torch>=1.8.0->ultralytics) (75.1.0)
# Requirement already satisfied: colorama in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\abelm\anaconda3\envs\lmdc\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.3.20-py3-none-any.whl (876 kB)
#    ---------------------------------------- 0.0/876.6 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/876.6 kB ? eta -:--:--
#    ---------------------------------------- 876.6/876.6 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.13
#     Uninstalling ultralytics-8.3.13:
#       Successfully uninstalled ultralytics-8.3.13
# Successfully installed ultralytics-8.3.20

# %%
import torch

print(torch.cuda.is_available())

if torch.cuda.is_available():
    print("Cuda is Availabe")
else:
    print("Cuda Can't be found")
# Out:
# False
# Cuda Can't be found

# %%
# Load a yolo pretrained model
model = YOLO('yolov8m.pt')

# Fine tune model to our data
model.train(
    data='data.yaml',          # Path to the dataset configuration
    epochs=30,                 # Number of epochs
    imgsz=2048,                # Image size (height, width)
    batch=8,                   # Batch size
    device=0,                  # Device to use (0 for the first GPU)
    patience=5)
# Out:
# New https://pypi.org/project/ultralytics/8.3.20 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.13  Python-3.12.7 torch-2.4.1+cpu
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 5
#       2 model = YOLO('yolov8m.pt')
#       4 # Fine tune model to our data
# ----> 5 model.train(
#       6     data='data.yaml',          # Path to the dataset configuration
#       7     epochs=30,                 # Number of epochs
#       8     imgsz=2048,                # Image size (height, width)
#       9     batch=8,                   # Batch size
#      10     device=0,                  # Device to use (0 for the first GPU)
#      11     patience=5)
#
# File ~\anaconda3\envs\lmdc\Lib\site-packages\ultralytics\engine\model.py:796, in Model.train(self, trainer, **kwargs)
#     793 if args.get("resume"):
#     794     args["resume"] = self.ckpt_path
# --> 796 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     797 if not args.get("resume"):  # manually set model only if not resuming
#     798     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File ~\anaconda3\envs\lmdc\Lib\site-packages\ultralytics\engine\trainer.py:103, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     101 self.args = get_cfg(cfg, overrides)
#     102 self.check_resume(overrides)
# --> 103 self.device = select_device(self.args.device, self.args.batch)
#     104 self.validator = None
#     105 self.metrics = None
#
# File ~\anaconda3\envs\lmdc\Lib\site-packages\ultralytics\utils\torch_utils.py:192, in select_device(device, batch, newline, verbose)
#     185         LOGGER.info(s)
#     186         install = (
#     187             "See https://pytorch.org/get-started/locally/ for up-to-date torch install instructions if no "
#     188             "CUDA devices are seen by torch.\n"
#     189             if torch.cuda.device_count() == 0
#     190             else ""
#     191         )
# --> 192         raise ValueError(
#     193             f"Invalid CUDA 'device={device}' requested."
#     194             f" Use 'device=cpu' or pass valid CUDA device(s) if available,"
#     195             f" i.e. 'device=0' or 'device=0,1,2,3' for Multi-GPU.\n"
#     196             f"\ntorch.cuda.is_available(): {torch.cuda.is_available()}"
#     197             f"\ntorch.cuda.device_count(): {torch.cuda.device_count()}"
#     198             f"\nos.environ['CUDA_VISIBLE_DEVICES']: {visible}\n"
#     199             f"{install}"
#     200         )
#     202 if not cpu and not mps and torch.cuda.is_available():  # prefer GPU if available
#     203     devices = device.split(",") if device else "0"  # i.e. "0,1" -> ["0", "1"]
#
# ValueError: Invalid CUDA 'device=0' requested. Use 'device=cpu' or pass valid CUDA device(s) if available, i.e. 'device=0' or 'device=0,1,2,3' for Multi-GPU.
#
# torch.cuda.is_available(): False
# torch.cuda.device_count(): 0
# os.environ['CUDA_VISIBLE_DEVICES']: 0
# See https://pytorch.org/get-started/locally/ for up-to-date torch install instructions if no CUDA devices are seen by torch.

# %%
# Validate the model on the validation set
model = YOLO('/runs/detect/train/weights/best.pt')
results = model.val()

# %%
# Load the trained YOLO model
model = YOLO('/runs/detect/train/weights/best.pt')

# Path to the test images directory
test_dir_path = '/datasets/dataset/images/test'

# Get a list of all image files in the test directory
image_files = os.listdir(test_dir_path)

# Initialize an empty list to store the results for all images
all_data = []

# Iterate through each image in the directory
for image_file in tqdm(image_files):
    # Full path to the image
    img_path = os.path.join(test_dir_path, image_file)

    # Make predictions on the image
    results = model(img_path)

    # Extract bounding boxes, confidence scores, and class labels
    boxes = results[0].boxes.xyxy.tolist()  # Bounding boxes in xyxy format
    classes = results[0].boxes.cls.tolist()  # Class indices
    confidences = results[0].boxes.conf.tolist()  # Confidence scores
    names = results[0].names  # Class names dictionary

    if not boxes:
        # If no detections, add NEG as the class
        all_data.append({
            'Image_ID': image_file,
            'class': 'NEG',
            'confidence': 1.0,  # You can set this to a default value
            'ymin': 0,  # Default value (no detection)
            'xmin': 0,  # Default value (no detection)
            'ymax': 0,  # Default value (no detection)
            'xmax': 0   # Default value (no detection)
        })
    else:
        # Iterate through the results for this image
        for box, cls, conf in zip(boxes, classes, confidences):
            x1, y1, x2, y2 = box
            detected_class = names[int(cls)]  # Get the class name from the names dictionary

            # Add the result to the all_data list
            all_data.append({
                'Image_ID': image_file,
                'class': detected_class,
                'confidence': conf,
                'ymin': y1,
                'xmin': x1,
                'ymax': y2,
                'xmax': x2
            })

# Convert the list to a DataFrame for all images
sub = pd.DataFrame(all_data)

# %%
sub.head()

# %%
sub['class'].value_counts()

# %%
# Create submission file to be uploaded to Zindi for scoring
sub.to_csv('benchmark_submission.csv', index = False)
